# %% [markdown]
# ![SNARs Project 2 by Amir Ali](https://pbs.twimg.com/media/FfSZsBbWQAAKdk0?format=jpg&name=medium)

# %% [markdown]
# In this project, we import four different datasets from different sources for visualize and analyze. <br>
#
# `Note`: Task is perform using Python

# %% [markdown]
# ![Machine Learning Project](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)

# %% [markdown]
# ### <font color = #950CDF> Part 1: </font> <font color = #4854E8> Import the Libraries </font>

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ![ML](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## <font color = #27C3E5> 1:</font> <font color = #41EA46> US_Edgelist Dataset </font>
# This dataset has two columns `from` and `To` and the information on different politics. Our target is to analyze and understand the connections.

# %% [markdown]
# ### <font color = blue> 1.1 Import and Understand the Dataset

# %%
df1 = pd.read_csv('us_edgelist.csv')
df1.head()
# Out:
#       From        To
# 0  Clinton   Hillary
# 1     Bush     Laura
# 2    Obama  Michelle
# 3    Trump    Ivanka
# 4  Clinton   G.Bush

# %%
# Read Our Edgelist
us_graph = nx.from_pandas_edgelist(df1,source="From",target="To")
type(us_graph)
# Out:
# networkx.classes.graph.Graph

# %%
# info of graph
nx.info(us_graph)
# Out:
# 'Graph with 19 nodes and 21 edges'

# %% [markdown]
# ### <font color = blue> 1.2 Check All Nodes/Object/People

# %%
us_graph.nodes()
# Out:
# NodeView(('Clinton', 'Hillary', 'Bush', 'Laura', 'Obama', 'Michelle', 'Trump', ' Ivanka', ' G.Bush ', 'Dole', 'Al Gore', 'Kerry', 'McCain', 'Romney', 'Bill', 'Ivanka', 'J. Thorn', 'T.Aitcheson', '\tCindy'))

# %% [markdown]
# ### <font color = blue> 1.3 Visualize the graph

# %%
plt.figure(figsize=(10,10))
nx.draw_networkx(us_graph)

# %% [markdown]
# ### <font color = blue> 1.4 Analysis the data
# + Degree of Centrality
# - Most Influential
# - Most important connection
# - Best betweener
# - Shortest Path

# %% [markdown]
# #### Degree Centrality
# + Most influential among them all
# + Who is the most influetial?
# + nx.degree_centrality(g)

# %%
nx.degree(us_graph)
# Out:
# DegreeView({'Clinton': 3, 'Hillary': 4, 'Bush': 5, 'Laura': 3, 'Obama': 5, 'Michelle': 4, 'Trump': 3, ' Ivanka': 1, ' G.Bush ': 1, 'Dole': 1, 'Al Gore': 2, 'Kerry': 2, 'McCain': 2, 'Romney': 1, 'Bill': 1, 'Ivanka': 1, 'J. Thorn': 1, 'T.Aitcheson': 1, '\tCindy': 1, 'Franklin': 1, 'Lincoln': 1})

# %%
most_influential = nx.degree_centrality(us_graph)
most_influential
# Out:
# {'Clinton': 0.15000000000000002,
#  'Hillary': 0.2,
#  'Bush': 0.25,
#  'Laura': 0.15000000000000002,
#  'Obama': 0.25,
#  'Michelle': 0.2,
#  'Trump': 0.15000000000000002,
#  ' Ivanka': 0.05,
#  ' G.Bush ': 0.05,
#  'Dole': 0.05,
#  'Al Gore': 0.1,
#  'Kerry': 0.1,
#  'McCain': 0.1,
#  'Romney': 0.05,
#  'Bill': 0.05,
#  'Ivanka': 0.05,
#  'J. Thorn': 0.05,
#  'T.Aitcheson': 0.05,
#  '\tCindy': 0.05,
#  'Franklin': 0.05,
#  'Lincoln': 0.05}

# %% [markdown]
# #### Eigenvector Centrality
# + Most important connection
# + Do you know whom I am related to?

# %%
most_important_link = nx.eigenvector_centrality(us_graph)
most_important_link
# Out:
# {'Clinton': 0.15152928713724503,
#  'Hillary': 0.38442159441543317,
#  'Bush': 0.3696180606401399,
#  'Laura': 0.36852963127385646,
#  'Obama': 0.4266565483896092,
#  'Michelle': 0.41352797669954305,
#  'Trump': 0.28433452527063385,
#  ' Ivanka': 0.08974661863249653,
#  ' G.Bush ': 0.04782770964575167,
#  'Dole': 0.04782770964575167,
#  'Al Gore': 0.12957724264199433,
#  'Kerry': 0.12957724264199433,
#  'McCain': 0.14957130173861363,
#  'Romney': 0.13466969692277045,
#  'Bill': 0.11666706333937449,
#  'Ivanka': 0.13052504916898053,
#  'J. Thorn': 0.04090043619100648,
#  'T.Aitcheson': 0.04090043619100648,
#  '\tCindy': 0.047210688306275804,
#  'Franklin': 6.994359082336066e-10,
#  'Lincoln': 6.994359082336066e-10}

# %% [markdown]
# #### Distance
# We can also determine the shortest path between two nodes and its length in NetworkX using
#  - nx.shortest_path(Graph, Node1, Node2)
#  - nx.shortest_path_length(Graph, Node1, Node2)

# %%
# shortest path
nx.shortest_path(us_graph,"Obama","Clinton")
# Out:
# ['Obama', 'Trump', 'Hillary', 'Clinton']

# %%
nx.shortest_path(us_graph,"Trump","Bush")
# Out:
# ['Trump', 'Obama', 'Bush']

# %% [markdown]
# #### Betweeness Centrality
# + Bridges /Betweener
# + Destiny Helpers or Connectors
# + Number of times a node is present in the shortest path between 2 other nodes
# + nx.betweenness_centrality(g)

# %%
nx.betweenness_centrality(us_graph)
# Out:
# {'Clinton': 0.17368421052631577,
#  'Hillary': 0.25789473684210523,
#  'Bush': 0.39473684210526316,
#  'Laura': 0.15789473684210525,
#  'Obama': 0.3526315789473684,
#  'Michelle': 0.14210526315789473,
#  'Trump': 0.13157894736842105,
#  ' Ivanka': 0.0,
#  ' G.Bush ': 0.0,
#  'Dole': 0.0,
#  'Al Gore': 0.08947368421052632,
#  'Kerry': 0.08947368421052632,
#  'McCain': 0.08947368421052632,
#  'Romney': 0.0,
#  'Bill': 0.0,
#  'Ivanka': 0.0,
#  'J. Thorn': 0.0,
#  'T.Aitcheson': 0.0,
#  '\tCindy': 0.0,
#  'Franklin': 0.0,
#  'Lincoln': 0.0}

# %% [markdown]
# ![ML](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## <font color = #27C3E5> 2:</font> <font color = #41EA46> Grey's Anatomy Dataset </font>
# This dataset has two columns `from` and `To` and the information on different actor of this drama. Our target is to analyze and understand the connections.

# %% [markdown]
# ### <font color = blue> 2.1 Import and Understand the Dataset

# %%
df2 = pd.read_csv("ga_edgelist.csv")
df2.head()
# Out:
#     from      to
# 0   lexi   sloan
# 1   lexi   karev
# 2   owen    yang
# 3   owen  altman
# 4  sloan  torres

# %%
# Read Our Edgelist
greys = nx.from_pandas_edgelist(df2,source="from",target="to")
type(us_graph)
# Out:
# networkx.classes.graph.Graph

# %%
# info of data
nx.info(greys)
# Out:
# 'Graph with 32 nodes and 34 edges'

# %% [markdown]
# ### <font color = blue> 2.2 Check All Nodes/Object/People

# %%
greys.nodes()
# Out:
# NodeView(('lexi', 'sloan', 'karev', 'owen', 'yang', 'altman', 'torres', 'arizona', 'derek', 'grey', 'izzie', "o'malley", 'colin', 'preston', 'kepner', 'addison', 'nancy', 'olivia', 'mrs. seabury', 'chief', 'adele', 'ellis grey', 'thatch grey', 'susan grey', 'bailey', 'tucker', 'hank', 'denny', 'finn', 'steve', 'ben', 'avery'))

# %%
# Check For All Edges /Connections
greys.edges
# Out:
# EdgeView([('lexi', 'sloan'), ('lexi', 'karev'), ('lexi', 'avery'), ('sloan', 'torres'), ('sloan', 'altman'), ('sloan', 'addison'), ('sloan', 'nancy'), ('karev', 'torres'), ('karev', 'izzie'), ('karev', 'kepner'), ('karev', 'addison'), ('karev', 'olivia'), ('karev', 'mrs. seabury'), ('owen', 'yang'), ('owen', 'altman'), ('yang', 'colin'), ('yang', 'preston'), ('torres', 'arizona'), ('torres', "o'malley"), ('derek', 'grey'), ('derek', 'addison'), ('grey', "o'malley"), ('grey', 'finn'), ('grey', 'steve'), ('izzie', "o'malley"), ('izzie', 'hank'), ('izzie', 'denny'), ("o'malley", 'olivia'), ('chief', 'adele'), ('chief', 'ellis grey'), ('ellis grey', 'thatch grey'), ('thatch grey', 'susan grey'), ('bailey', 'tucker'), ('bailey', 'ben')])

# %% [markdown]
# ### <font color = blue> 2.3 Visualize the graph

# %%
plt.figure(figsize=(10,10))
nx.draw_networkx(greys)
plt.show()

# %% [markdown]
# ### <font color = blue> Analysis the Network Data
# + Degree of Centrality
# - Most Influential
# - Most important connection
# - Best betweener
# - Shortest Path

# %% [markdown]
# #### Degree Centrality
# + Most influential among them all
# + Who is the most influetial?
# + nx.degree_centrality(g)

# %%
nx.degree(greys)
# Out:
# DegreeView({'lexi': 3, 'sloan': 5, 'karev': 7, 'owen': 2, 'yang': 3, 'altman': 2, 'torres': 4, 'arizona': 1, 'derek': 2, 'grey': 4, 'izzie': 4, "o'malley": 4, 'colin': 1, 'preston': 1, 'kepner': 1, 'addison': 3, 'nancy': 1, 'olivia': 2, 'mrs. seabury': 1, 'chief': 2, 'adele': 1, 'ellis grey': 2, 'thatch grey': 2, 'susan grey': 1, 'bailey': 2, 'tucker': 1, 'hank': 1, 'denny': 1, 'finn': 1, 'steve': 1, 'ben': 1, 'avery': 1})

# %%
most_influential = nx.degree_centrality(greys)
most_influential
# Out:
# {'lexi': 0.0967741935483871,
#  'sloan': 0.16129032258064516,
#  'karev': 0.22580645161290322,
#  'owen': 0.06451612903225806,
#  'yang': 0.0967741935483871,
#  'altman': 0.06451612903225806,
#  'torres': 0.12903225806451613,
#  'arizona': 0.03225806451612903,
#  'derek': 0.06451612903225806,
#  'grey': 0.12903225806451613,
#  'izzie': 0.12903225806451613,
#  "o'malley": 0.12903225806451613,
#  'colin': 0.03225806451612903,
#  'preston': 0.03225806451612903,
#  'kepner': 0.03225806451612903,
#  'addison': 0.0967741935483871,
#  'nancy': 0.03225806451612903,
#  'olivia': 0.06451612903225806,
#  'mrs. seabury': 0.03225806451612903,
#  'chief': 0.06451612903225806,
#  'adele': 0.03225806451612903,
#  'ellis grey': 0.06451612903225806,
#  'thatch grey': 0.06451612903225806,
#  'susan grey': 0.03225806451612903,
#  'bailey': 0.06451612903225806,
#  'tucker': 0.03225806451612903,
#  'hank': 0.03225806451612903,
#  'denny': 0.03225806451612903,
#  'finn': 0.03225806451612903,
# ...

# %% [markdown]
# #### Eigenvector Centrality
# + Most important connection
# + Do you know whom I am related to?

# %%
most_important_link = nx.eigenvector_centrality(greys)
most_important_link
# Out:
# {'lexi': 0.26424680180934534,
#  'sloan': 0.3226885189834077,
#  'karev': 0.502765929935718,
#  'owen': 0.0340951785615966,
#  'yang': 0.012046878049189772,
#  'altman': 0.10443160377884472,
#  'torres': 0.3609266644703912,
#  'arizona': 0.10564217608811323,
#  'derek': 0.12570927644873783,
#  'grey': 0.15107970429307171,
#  'izzie': 0.2842593314893894,
#  "o'malley": 0.3020100450564303,
#  'colin': 0.0035273360425288774,
#  'preston': 0.0035273360425288774,
#  'kepner': 0.14715740970512992,
#  'addison': 0.2784034899141397,
#  'nancy': 0.09445089593868505,
#  'olivia': 0.235554604339933,
#  'mrs. seabury': 0.14715740970512992,
#  'chief': 1.0663186023876088e-06,
#  'adele': 6.156393321318697e-07,
#  'ellis grey': 1.2312786642593052e-06,
#  'thatch grey': 1.0663186023876088e-06,
#  'susan grey': 6.156393321318697e-07,
#  'bailey': 4.7944137268011994e-08,
#  'tucker': 3.390162458034995e-08,
#  'hank': 0.0832011015170876,
#  'denny': 0.0832011015170876,
# ...

# %% [markdown]
# #### Distance
# We can also determine the shortest path between two nodes and its length in NetworkX using
#  - nx.shortest_path(Graph, Node1, Node2)
#  - nx.shortest_path_length(Graph, Node1, Node2)

# %%
# shortest path
nx.shortest_path(greys,"grey","denny")
# Out:
# ['grey', "o'malley", 'izzie', 'denny']

# %% [markdown]
# #### Betweeness Centrality
# + Bridges /Betweener
# + Destiny Helpers or Connectors
# + Number of times a node is present in the shortest path between 2 other nodes
# + nx.betweenness_centrality(g)

# %%
nx.betweenness_centrality(greys)
# Out:
# {'lexi': 0.07741935483870968,
#  'sloan': 0.248100358422939,
#  'karev': 0.2048745519713262,
#  'owen': 0.12903225806451613,
#  'yang': 0.09247311827956989,
#  'altman': 0.16344086021505377,
#  'torres': 0.14440860215053763,
#  'arizona': 0.0,
#  'derek': 0.038602150537634404,
#  'grey': 0.10078853046594982,
#  'izzie': 0.10311827956989246,
#  "o'malley": 0.11702508960573477,
#  'colin': 0.0,
#  'preston': 0.0,
#  'kepner': 0.0,
#  'addison': 0.09480286738351255,
#  'nancy': 0.0,
#  'olivia': 0.01064516129032258,
#  'mrs. seabury': 0.0,
#  'chief': 0.0064516129032258064,
#  'adele': 0.0,
#  'ellis grey': 0.008602150537634409,
#  'thatch grey': 0.0064516129032258064,
#  'susan grey': 0.0,
#  'bailey': 0.002150537634408602,
#  'tucker': 0.0,
#  'hank': 0.0,
#  'denny': 0.0,
#  'finn': 0.0,
#  'steve': 0.0,
#  'ben': 0.0,
#  'avery': 0.0}

# %% [markdown]
# ![ML](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## <font color = #27C3E5> 3:</font> <font color = #41EA46> Books Dataset </font>
# This dataset has two columns `source` and `target` and the information on different books. Our target is to analyze and understand the connections.

# %% [markdown]
# ### <font color = blue> 3.1 Import and Understand the Dataset

# %%
df3 = pd.read_csv("book1.csv", usecols = [0, 1])
df3.head()
# Out:
#                             Source              Target
# 0                   Addam-Marbrand     Jaime-Lannister
# 1                   Addam-Marbrand     Tywin-Lannister
# 2                Aegon-I-Targaryen  Daenerys-Targaryen
# 3                Aegon-I-Targaryen        Eddard-Stark
# 4  Aemon-Targaryen-(Maester-Aemon)      Alliser-Thorne

# %%
# Read Our Edgelist
book = nx.from_pandas_edgelist(df2,source="Source",target="Target")
type(book)
# Out:
# networkx.classes.graph.Graph

# %%
# info of data
nx.info(book)
# Out:
# 'Graph with 187 nodes and 684 edges'

# %% [markdown]
# ### <font color = blue> 3.2 Check All Nodes/Object/People

# %%
book.nodes()
# Out:
# NodeView(('Addam-Marbrand', 'Jaime-Lannister', 'Tywin-Lannister', 'Aegon-I-Targaryen', 'Daenerys-Targaryen', 'Eddard-Stark', 'Aemon-Targaryen-(Maester-Aemon)', 'Alliser-Thorne', 'Bowen-Marsh', 'Chett', 'Clydas', 'Jeor-Mormont', 'Jon-Snow', 'Samwell-Tarly', 'Aerys-II-Targaryen', 'Brandon-Stark', 'Gerold-Hightower', 'Jon-Arryn', 'Robert-Baratheon', 'Aggo', 'Drogo', 'Jhogo', 'Jorah-Mormont', 'Quaro', 'Rakharo', 'Albett', 'Halder', 'Rast', 'Grenn', 'Pypar', 'Tyrion-Lannister', 'Alyn', 'Harwin', 'Jory-Cassel', 'Tomard', 'Arthur-Dayne', 'Arya-Stark', 'Benjen-Stark', 'Bran-Stark', 'Catelyn-Stark', 'Cersei-Lannister', 'Desmond', 'Ilyn-Payne', 'Jeyne-Poole', 'Joffrey-Baratheon', 'Meryn-Trant', 'Mordane', 'Mycah', 'Myrcella-Baratheon', 'Petyr-Baelish', 'Rickon-Stark', 'Robb-Stark', 'Rodrik-Cassel', 'Sandor-Clegane', 'Sansa-Stark', 'Syrio-Forel', 'Tommen-Baratheon', 'Vayon-Poole', 'Yoren', 'Arys-Oakheart', 'Balon-Greyjoy', 'Balon-Swann', 'Renly-Baratheon', 'Barristan-Selmy', 'Boros-Blount', 'Py
# ...

# %%
# Check For All Edges /Connections
book.edges
# Out:
# EdgeView([('Addam-Marbrand', 'Jaime-Lannister'), ('Addam-Marbrand', 'Tywin-Lannister'), ('Jaime-Lannister', 'Aerys-II-Targaryen'), ('Jaime-Lannister', 'Barristan-Selmy'), ('Jaime-Lannister', 'Brynden-Tully'), ('Jaime-Lannister', 'Catelyn-Stark'), ('Jaime-Lannister', 'Cersei-Lannister'), ('Jaime-Lannister', 'Eddard-Stark'), ('Jaime-Lannister', 'Edmure-Tully'), ('Jaime-Lannister', 'Galbart-Glover'), ('Jaime-Lannister', 'Gregor-Clegane'), ('Jaime-Lannister', 'Harys-Swyft'), ('Jaime-Lannister', 'Joffrey-Baratheon'), ('Jaime-Lannister', 'Jon-Arryn'), ('Jaime-Lannister', 'Jory-Cassel'), ('Jaime-Lannister', 'Kevan-Lannister'), ('Jaime-Lannister', 'Loras-Tyrell'), ('Jaime-Lannister', 'Lysa-Arryn'), ('Jaime-Lannister', 'Petyr-Baelish'), ('Jaime-Lannister', 'Renly-Baratheon'), ('Jaime-Lannister', 'Rickard-Karstark'), ('Jaime-Lannister', 'Robb-Stark'), ('Jaime-Lannister', 'Robert-Baratheon'), ('Jaime-Lannister', 'Rodrik-Cassel'), ('Jaime-Lannister', 'Sandor-Clegane'), ('Jaime-Lannister', 'Sansa
# ...

# %% [markdown]
# ### <font color = blue> 3.3 Visualize the graph

# %%
plt.figure(figsize=(20,20))
nx.draw_networkx(book)
plt.show()

# %% [markdown]
# ### <font color = blue> 3.4: Analysis the Network Data
# + Degree of Centrality
# - Most Influential
# - Most important connection
# - Best betweener
# - Shortest Path

# %% [markdown]
# #### Degree Centrality
# + Most influential among them all
# + Who is the most influetial?
# + nx.degree_centrality(g)

# %%
nx.degree(book)
# Out:
# DegreeView({'Addam-Marbrand': 2, 'Jaime-Lannister': 29, 'Tywin-Lannister': 22, 'Aegon-I-Targaryen': 2, 'Daenerys-Targaryen': 21, 'Eddard-Stark': 66, 'Aemon-Targaryen-(Maester-Aemon)': 7, 'Alliser-Thorne': 10, 'Bowen-Marsh': 5, 'Chett': 3, 'Clydas': 1, 'Jeor-Mormont': 13, 'Jon-Snow': 37, 'Samwell-Tarly': 12, 'Aerys-II-Targaryen': 6, 'Brandon-Stark': 6, 'Gerold-Hightower': 5, 'Jon-Arryn': 15, 'Robert-Baratheon': 50, 'Aggo': 6, 'Drogo': 19, 'Jhogo': 6, 'Jorah-Mormont': 13, 'Quaro': 5, 'Rakharo': 5, 'Albett': 3, 'Halder': 8, 'Rast': 6, 'Grenn': 7, 'Pypar': 7, 'Tyrion-Lannister': 46, 'Alyn': 5, 'Harwin': 4, 'Jory-Cassel': 21, 'Tomard': 7, 'Arthur-Dayne': 1, 'Arya-Stark': 27, 'Benjen-Stark': 14, 'Bran-Stark': 32, 'Catelyn-Stark': 43, 'Cersei-Lannister': 30, 'Desmond': 2, 'Ilyn-Payne': 9, 'Jeyne-Poole': 6, 'Joffrey-Baratheon': 30, 'Meryn-Trant': 9, 'Mordane': 11, 'Mycah': 5, 'Myrcella-Baratheon': 7, 'Petyr-Baelish': 26, 'Rickon-Stark': 9, 'Robb-Stark': 35, 'Rodrik-Cassel': 18, 'Sandor-Clega
# ...

# %%
most_influential = nx.degree_centrality(book)
most_influential
# Out:
# {'Addam-Marbrand': 0.010752688172043012,
#  'Jaime-Lannister': 0.15591397849462366,
#  'Tywin-Lannister': 0.11827956989247312,
#  'Aegon-I-Targaryen': 0.010752688172043012,
#  'Daenerys-Targaryen': 0.11290322580645162,
#  'Eddard-Stark': 0.3548387096774194,
#  'Aemon-Targaryen-(Maester-Aemon)': 0.03763440860215054,
#  'Alliser-Thorne': 0.05376344086021506,
#  'Bowen-Marsh': 0.02688172043010753,
#  'Chett': 0.016129032258064516,
#  'Clydas': 0.005376344086021506,
#  'Jeor-Mormont': 0.06989247311827958,
#  'Jon-Snow': 0.19892473118279572,
#  'Samwell-Tarly': 0.06451612903225806,
#  'Aerys-II-Targaryen': 0.03225806451612903,
#  'Brandon-Stark': 0.03225806451612903,
#  'Gerold-Hightower': 0.02688172043010753,
#  'Jon-Arryn': 0.08064516129032259,
#  'Robert-Baratheon': 0.2688172043010753,
#  'Aggo': 0.03225806451612903,
#  'Drogo': 0.10215053763440861,
#  'Jhogo': 0.03225806451612903,
#  'Jorah-Mormont': 0.06989247311827958,
#  'Quaro': 0.02688172043010753,
# ...

# %% [markdown]
# #### Eigenvector Centrality
# + Most important connection
# + Do you know whom I am related to?

# %%
most_important_link = nx.eigenvector_centrality(book)
most_important_link
# Out:
# {'Addam-Marbrand': 0.01690662287534132,
#  'Jaime-Lannister': 0.19495798576036363,
#  'Tywin-Lannister': 0.13939046584052592,
#  'Aegon-I-Targaryen': 0.017384680879533473,
#  'Daenerys-Targaryen': 0.047389349606781005,
#  'Eddard-Stark': 0.29640893871843454,
#  'Aemon-Targaryen-(Maester-Aemon)': 0.01572891559042457,
#  'Alliser-Thorne': 0.02884644061917081,
#  'Bowen-Marsh': 0.015169602126328254,
#  'Chett': 0.010824124243907149,
#  'Clydas': 0.0007954157740942035,
#  'Jeor-Mormont': 0.05708614464400136,
#  'Jon-Snow': 0.17046044936828572,
#  'Samwell-Tarly': 0.027862966057814832,
#  'Aerys-II-Targaryen': 0.04858263408723131,
#  'Brandon-Stark': 0.044018473716797464,
#  'Gerold-Hightower': 0.031231471653479878,
#  'Jon-Arryn': 0.12467394372126449,
#  'Robert-Baratheon': 0.2694880017758138,
#  'Aggo': 0.0054811307155646334,
#  'Drogo': 0.02259083571954164,
#  'Jhogo': 0.00571204867284141,
#  'Jorah-Mormont': 0.024102672246267703,
#  'Quaro': 0.004319920160802585,
# ...

# %% [markdown]
# #### Distance
# We can also determine the shortest path between two nodes and its length in NetworkX using
#  - nx.shortest_path(Graph, Node1, Node2)
#  - nx.shortest_path_length(Graph, Node1, Node2)

# %%
# shortest path
nx.shortest_path(book,"Addam-Marbrand","Chett")
# Out:
# ['Addam-Marbrand', 'Jaime-Lannister', 'Catelyn-Stark', 'Jon-Snow', 'Chett']

# %% [markdown]
# #### Betweeness Centrality
# + Bridges /Betweener
# + Destiny Helpers or Connectors
# + Number of times a node is present in the shortest path between 2 other nodes
# + nx.betweenness_centrality(g)

# %%
nx.betweenness_centrality(book)
# Out:
# {'Addam-Marbrand': 0.0,
#  'Jaime-Lannister': 0.0320095542681723,
#  'Tywin-Lannister': 0.026190475931508066,
#  'Aegon-I-Targaryen': 0.0,
#  'Daenerys-Targaryen': 0.08627015537511595,
#  'Eddard-Stark': 0.2696038913836117,
#  'Aemon-Targaryen-(Maester-Aemon)': 0.010844715683425361,
#  'Alliser-Thorne': 0.005026701469957172,
#  'Bowen-Marsh': 0.0,
#  'Chett': 0.0,
#  'Clydas': 0.0,
#  'Jeor-Mormont': 0.028345621007255038,
#  'Jon-Snow': 0.17158135899829566,
#  'Samwell-Tarly': 0.014449634885820021,
#  'Aerys-II-Targaryen': 0.00048173749786653005,
#  'Brandon-Stark': 0.002080261918971597,
#  'Gerold-Hightower': 0.02144725370531822,
#  'Jon-Arryn': 0.012525043642810938,
#  'Robert-Baratheon': 0.21403028397371796,
#  'Aggo': 7.265329845975008e-05,
#  'Drogo': 0.06481224290874964,
#  'Jhogo': 4.359197907585004e-05,
#  'Jorah-Mormont': 0.012611106728154204,
#  'Quaro': 2.906131938390003e-05,
#  'Rakharo': 3.390487261455003e-05,
#  'Albett': 0.0,
#  'Halder': 0.0002102102102102102,
# ...

# %% [markdown]
# ![ML](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## <font color = #27C3E5> 4:</font> <font color = #41EA46> Twitter Snap Dataset </font>
# This dataset consists of 'circles' (or 'lists') from Twitter. Twitter data was crawled from public sources. The dataset includes node features (profiles), circles, and ego networks.

# %% [markdown]
# ### <font color = blue> 4.1 Import the Dataset

# %%
G1 =nx.read_edgelist("twitter.txt", create_using = nx.Graph(), nodetype=int)
print(nx.info(G1))
# Out:
# Graph with 133 nodes and 159 edges

# %% [markdown]
# ### <font color = blue> 4.2 Method of Analysis

# %% [markdown]
# #### 4.2.1. Betweenness Centrality

# %%
pos = nx.spring_layout(G1)
betCent = nx.betweenness_centrality(G1, normalized=True, endpoints=True)
node_color = [20000.0 * G1.degree(v) for v in G1]
node_size =  [v * 10000 for v in betCent.values()]
plt.figure(figsize=(20,20))
nx.draw_networkx(G1, pos=pos, with_labels=False,
                 node_color=node_color,
                 node_size=node_size )
plt.axis('off')
sorted(betCent, key=betCent.get, reverse=True)[:5]
# Out:
# [100581193, 151338729, 279787626, 358775055, 153226312]

# %% [markdown]
# #### 4.2.2. Degree Centrality

# %%
pos = nx.spring_layout(G1)
degCent = nx.degree_centrality(G1)
node_color = [20000.0 * G1.degree(v) for v in G1]
node_size =  [v * 10000 for v in degCent.values()]
plt.figure(figsize=(15,15))
nx.draw_networkx(G1, pos=pos, with_labels=False,
                 node_color=node_color,
                 node_size=node_size )
plt.axis('off')

sorted(degCent, key=degCent.get, reverse=True)[:5]
# Out:
# [153226312, 151338729, 67864340, 31331740, 100581193]

# %%
sorted(degCent, key=degCent.get, reverse=True)[:5]
# Out:
# [153226312, 151338729, 67864340, 31331740, 100581193]

# %% [markdown]
# #### 4.2.3.  Closeness Centrality

# %%
pos = nx.spring_layout(G1)
cloCent = nx.closeness_centrality(G1)
node_color = [20000.0 * G1.degree(v) for v in G1]
node_size =  [v * 10000 for v in cloCent.values()]
plt.figure(figsize=(13,13))
nx.draw_networkx(G1, pos=pos, with_labels=False,
                 node_color=node_color,
                 node_size=node_size )
plt.axis('off')
sorted(cloCent, key=cloCent.get, reverse=True)[:5]
# Out:
# [100581193, 187773078, 151338729, 279787626, 222261763]

# %% [markdown]
# #### 4.2.4. Degree Graph

# %%
max(x for x,y in nx.degree(G1))
# Out:
# 529007327

# %% [markdown]
# #### 4.2.5. Find Shortest Path

# %%
sources = [103598216]
targets = [22462180] 
for i in range(1):
    path = nx.shortest_path(G1,source=sources[i],target=targets[i])
    length = nx.shortest_path_length(G1,source=sources[i],target=targets[i],method='dijkstra')
    print("Shortest Path between Node ", str(sources[i])," ---> ", str(targets[i]), " is ",
          str(path), " ,Length = ", str(length))
# Out:
# Shortest Path between Node  103598216  --->  22462180  is  [103598216, 206923844, 279787626, 100581193, 358775055, 117674417, 117901353, 116498875, 22462180]  ,Length =  8

# %% [markdown]
# #### 4.2.6. Eigenvector Centrality

# %%
#pos = nx.spring_layout(G1)
eigCent = nx.eigenvector_centrality(G1)
node_color = [20000.0 * G1.degree(v) for v in G1]
node_size =  [v * 10000 for v in eigCent.values()]
plt.figure(figsize=(15,15))
nx.draw_networkx(G1, pos=pos, with_labels=False,
                 node_color=node_color,
                 node_size=node_size )
plt.axis('off')
# Out:
# (-1.2060820490602377,
#  1.1687682305863132,
#  -0.851146521188095,
#  1.162714255014201)

# %%
sorted(eigCent, key=eigCent.get, reverse=True)[:5]
# Out:
# [153226312, 151338729, 187773078, 67864340, 100581193]

# %% [markdown]
# ![Machine Learning Project](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
