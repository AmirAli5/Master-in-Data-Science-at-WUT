# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\User\\Documents\\Studia\\NLP\\project2\\src'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.sequence import pad_sequences
plt.style.use("fivethirtyeight")

# %%
name = 'own_lstm'
data = '../data/own_mod.parquet'

# %% [markdown]
# ## 1: Load data

# %%
df = pd.read_parquet(data)
df
# Out:
#                                                    text  score
# 0     description say maybe cream cheese cream chees...      1
# 1     terrible followed recipe exactly tasted fine a...      1
# 2     im always amazed people rate recipe state chan...      1
# 3     didnt like creamy rich didnt feel good sour cr...      1
# 4              even using green chilies much hot u like      1
# ...                                                 ...    ...
# 1407  good omitted green chilies dont like lot heat ...      5
# 1408  cut calorie fat way using nonfat sour cream su...      5
# 1409  wonderful recipe used oz light cream cheese in...      5
# 1410  good thing would leave salt use lower sodium b...      5
# 1411  quick easy make family asks time dont add gree...      5
#
# [1412 rows x 2 columns]

# %% [markdown]
# ### 2.3 Feature Extraction

# %% [markdown]
# #### 2.3.1 Tokenization

# %%
n_words = 2000

from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(num_words=n_words)
tokenizer.fit_on_texts(df.text)
total_words = len(tokenizer.word_index) + 1
total_words
# Out:
# 3450

# %%
X = tokenizer.texts_to_sequences(df.text)
X
# Out:
# [[901, 116, 86, 10, 17, 10, 17, 1, 53, 116, 43, 10, 195, 10, 10, 17],
#  [271, 59, 1, 87, 117, 375, 9, 43, 10, 195, 10, 74, 261, 54, 1049, 18, 602],
#  [67,
#   141,
#   1050,
#   149,
#   794,
#   1,
#   643,
#   349,
#   1,
#   1750,
#   331,
#   488,
#   60,
#   226,
#   67,
#   96,
#   902,
#   36,
#   40,
#   1,
#   149,
#   167,
#   1,
#   123,
#   1313,
#   1751,
#   168,
#   175,
#   1,
#   5,
#   36,
#   1314,
#   794],
#  [20, 5, 262, 304, 20, 514, 4, 43, 10, 112, 195, 10, 1315, 1051, 51, 195, 10],
#  [36, 190, 61, 204, 24, 191, 251, 5],
#  [1316, 18, 1752, 49, 18, 7, 1753, 18, 30, 54, 14, 18, 1754],
#  [3, 7, 5, 168, 1, 400, 13, 2, 454, 1, 89, 62, 75],
#  [376,
#   1052,
#   1,
#   8,
#   118,
#   1755,
#   263,
#   30,
#   24,
#   1756,
#   176,
#   1053,
#   1317,
#   1318,
#   720,
#   51,
#   47],
#  [141,
#   176,
#   118,
#   47,
#   1,
#   1757,
#   1758,
#   102,
#   1,
#   177,
#   196,
#   205,
#   116,
#   4,
#   13,
#   206,
#   150,
#   65,
#   432,
#   86,
#   104,
#   105,
#   555,
#   401,
#   183,
#   252,
#   5,
#   11,
#   903,
#   1759,
#   1760],
#  [59,
#   1,
#   1761,
#   142,
#   210,
#   1762,
#   904,
#   1763,
#   113,
#   316,
#   1764,
#   148,
#   230,
#   1765,
#   52,
#   1054,
#   1766,
#   16,
#   1767,
#   515,
#   52,
#   1768],
#  [63,
#   6,
#   8,
#   489,
#   1769,
#   1,
#   8,
#   98,
#   12,
#   143,
#   13,
#   23,
#   241,
#   556,
#   162,
#   83,
#   169,
#   135,
#   1,
#   205],
#  [1, 1770, 1771, 490, 1772],
#  [47, 271, 230, 75, 83, 721, 1773, 305, 644, 332, 192, 53],
#  [1774, 1, 1055, 557, 1775, 51, 1776, 1777],
#  [1778, 905, 1779, 18, 93, 3, 377],
#  [78, 795, 1780, 402, 44, 24, 51, 1, 132, 1781, 1319, 1782, 1783, 205],
#  [211,
#   37,
#   1,
#   159,
#   4,
#   78,
#   1320,
#   159,
#   5,
#   1784,
#   11,
#   36,
#   796,
#   175,
#   17,
#   272,
#   1056,
#   17,
#   67,
#   205,
#   455,
#   5,
#   1785,
#   272,
#   282,
#   175,
#   17],
#  [21,
#   377,
#   2,
#   18,
#   331,
#   19,
#   48,
#   273,
#   13,
#   48,
#   226,
#   106,
#   722,
#   402,
#   1057,
#   123,
#   491,
#   433,
#   37,
#   402,
#   1057,
#   11,
#   51,
#   57,
#   3,
#   15,
#   170,
#   317,
#   64,
#   136],
#  [1786,
#   645,
#   1,
#   193,
#   646,
#   402,
#   44,
#   1321,
#   723,
#   17,
#   1322,
#   516,
#   906,
#   350,
#   434,
#   159,
#   5,
#   402,
#   1057,
#   489,
#   517,
#   797,
#   378,
#   44,
#   1323,
#   125,
#   119,
#   1321,
#   647,
#   723,
#   17,
#   137,
#   137,
#   67,
#   724,
#   379,
#   20,
#   333,
#   1324,
#   1325,
#   54,
#   47,
#   603,
#   798,
#   1787],
#  [20, 5, 30, 24, 17, 456, 7, 59, 63, 50, 114, 46, 17, 242, 1326, 295, 30],
#  [59, 1, 87, 1058, 12, 558, 114, 17, 107, 296, 4, 11],
#  [21, 20, 136, 18, 205, 116, 318, 253, 192, 6, 60, 212, 297, 51],
#  [59, 1, 87, 7, 97, 3, 144, 129, 102, 50, 319, 76, 1059, 86, 61, 56, 125, 604],
#  [79],
#  [3,
#   1788,
#   518,
#   605,
#   518,
#   178,
#   93,
#   1789,
#   25,
#   3,
#   1060,
#   283,
#   403,
#   318,
#   519,
#   7,
#   264,
#   89,
#   19,
#   518,
#   178,
#   1790],
#  [30, 24, 17, 23, 133, 149, 435],
#  [167, 520, 40],
#  [1327,
#   40,
#   1791,
#   298,
#   32,
#   364,
#   907,
#   380,
#   3,
#   1,
#   190,
#   53,
#   648,
#   379,
#   87,
#   28,
#   96,
#   176,
#   163,
#   725,
#   284,
#   78,
#   559,
#   380,
#   1061,
#   1792,
#   1793,
#   78,
#   37,
#   145,
#   171,
#   606,
#   231,
#   13,
#   126,
#   211,
#   168,
#   1794,
#   213,
#   21,
#   1062,
#   72,
#   351,
#   168,
#   21,
#   649,
#   214,
#   115,
#   151,
#   192],
#  [79, 154, 650, 59, 1, 519, 24, 457, 650, 67, 1795],
#  [32, 1, 908],
#  [521,
#   38,
#   18,
#   78,
#   168,
#   1328,
#   517,
#   15,
#   607,
#   435,
#   560,
#   243,
#   81,
#   726,
#   1,
#   492,
#   493,
#   1796,
#   1,
#   909],
#  [3,
#   38,
#   727,
#   215,
#   226,
#   48,
#   3,
#   89,
#   38,
#   799,
#   352,
#   93,
#   1797,
#   8,
#   1329,
#   108,
#   1,
#   13,
#   130,
#   5,
#   297,
#   108,
#   296,
#   608,
#   52,
#   38,
#   332,
#   1330,
#   81,
#   651,
#   184,
#   232,
#   97,
#   436,
#   1,
#   77,
#   909,
#   69,
#   124,
#   30,
#   910,
#   911,
#   1798,
#   1063,
#   652,
#   1,
#   728,
#   2,
#   124,
#   1331,
#   437],
#  [1, 1332, 68, 243, 162, 38, 36, 1799, 91],
#  [456,
#   226,
#   48,
#   438,
#   210,
#   109,
#   306,
#   1064,
#   65,
#   81,
#   120,
#   130,
#   243,
#   8,
#   197,
#   912,
#   609,
#   561,
#   60,
#   145,
#   98,
#   216,
#   1065,
#   81,
#   38,
#   608,
#   38,
#   562,
#   800,
#   381,
#   192,
#   1800],
#  [352,
#   81,
#   38,
#   130,
#   1,
#   93,
#   59,
#   379,
#   87,
#   150,
#   729,
#   52,
#   63,
#   653,
#   801,
#   31,
#   243,
#   67,
#   1801,
#   12,
#   25,
#   654,
#   610,
#   92,
#   1],
#  [264, 1, 198, 6, 30, 24, 232, 38, 913, 232],
#  [271, 296, 4, 206, 142, 52, 651, 243, 148, 377, 2, 38, 320, 494, 253, 7, 264],
#  [38, 74, 608, 52, 307, 243, 802, 42, 803],
#  [59, 1, 563, 38, 296, 19, 804, 365, 332, 805, 2, 264],
#  [148, 5, 18, 1066, 243, 81, 75, 493],
#  [38, 1802, 42, 16, 105, 33],
#  [30, 522],
#  [64,
#   5,
#   41,
#   85,
#   16,
#   80,
#   85,
#   50,
#   162,
#   85,
#   230,
#   145,
#   146,
#   27,
#   126,
#   85,
#   523,
#   164,
#   458,
#   25,
#   1803,
#   1067,
#   162,
#   142,
#   177,
#   109,
#   1333,
#   321,
#   1334],
#  [64, 20, 5, 1, 1804, 1805, 37, 155, 179],
#  [5],
#  [13, 352, 1, 93, 102, 646, 459, 730, 1806, 61, 1807, 318, 192, 6, 1068],
#  [26, 20, 5, 404, 432],
#  [655, 655, 656, 26, 136, 304, 806, 17],
#  [405,
#   92,
#   103,
#   9,
#   524,
#   66,
#   34,
#   148,
#   564,
#   332,
#   152,
#   657,
#   199,
#   156,
#   73,
#   8,
#   34,
#   163,
#   123,
#   114,
#   200,
#   37,
#   109,
#   521,
#   731,
#   207,
#   84,
#   1808,
#   404,
#   1335,
#   801,
#   1809,
#   1810,
#   914],
#  [285, 36, 366, 1811, 1812, 658, 1813, 4, 404],
#  [78, 263, 565, 915, 659, 17, 566],
#  [566, 207, 198, 192, 6, 525],
#  [406,
#   1,
#   433,
#   233,
#   724,
#   74,
#   916,
#   1336,
#   53,
#   299,
#   660,
#   7,
#   274,
#   221,
#   460,
#   19,
#   48,
#   661,
#   62,
#   275,
#   731,
#   84,
#   34,
#   263,
#   461,
#   12,
#   30,
#   662,
#   526,
#   283,
#   222,
#   807,
#   25,
#   84,
#   461,
#   491,
#   1,
#   89,
#   88,
#   20,
#   5,
#   144,
#   192,
#   132,
#   6,
#   78,
#   192,
#   6],
#  [1337, 663, 48, 732, 24, 59, 1, 87, 191, 611, 23, 733, 84, 2, 185, 2],
#  [322,
#   602,
#   1,
#   23,
#   12,
#   244,
#   1069,
#   379,
#   1814,
#   137,
#   31,
#   200,
#   567,
#   439,
#   21,
#   917,
#   112,
#   407,
#   378,
#   408,
#   73,
#   1],
#  [334, 42],
#  [1, 285],
#  [59, 1, 1815],
#  [24,
#   51,
#   54,
#   47,
#   1,
#   1,
#   16,
#   90,
#   367,
#   200,
#   2,
#   24,
#   51,
#   47,
#   808,
#   568,
#   16,
#   603,
#   382],
#  [286,
#   459,
#   566,
#   495,
#   383,
#   300,
#   52,
#   108,
#   918,
#   569,
#   37,
#   1,
#   1338,
#   226,
#   31,
#   200,
#   31,
#   41,
#   384,
#   15,
#   197,
#   1816,
#   1070,
#   73,
#   462,
#   570,
#   368,
#   15,
#   41],
#  [1,
#   496,
#   1326,
#   50,
#   7,
#   2,
#   409,
#   74,
#   406,
#   1339,
#   271,
#   47,
#   440,
#   67,
#   96,
#   734,
#   67,
#   96,
#   129,
#   496,
#   47,
#   1,
#   661,
#   62,
#   72,
#   7,
#   99,
#   1340,
#   3,
#   47,
#   141,
#   74,
#   19,
#   59,
#   201,
#   1341,
#   664,
#   8,
#   47,
#   41,
#   35,
#   1817,
#   41,
#   92,
#   67,
#   1342,
#   494,
#   1,
#   519,
#   665,
#   28,
#   47,
#   1343,
#   1344,
#   1345,
#   110,
#   1345,
#   2,
#   45,
#   47,
#   274,
#   4,
#   287,
#   6],
#  [1065, 59, 1, 1818, 47, 20, 440, 96, 1819, 222, 41, 20, 440, 145, 323, 282],
#  [92,
#   47,
#   666,
#   527,
#   70,
#   385,
#   78,
#   37,
#   93,
#   9,
#   527,
#   70,
#   301,
#   3,
#   50,
#   47,
#   117,
#   285,
#   20,
#   809,
#   227,
#   8,
#   735,
#   227,
#   1346,
#   83,
#   1820,
#   96,
#   88,
#   301,
#   285,
#   11,
#   28],
#  [199,
#   919,
#   493,
#   528,
#   463,
#   222,
#   529,
#   15,
#   34,
#   920,
#   42,
#   368,
#   36,
#   1071,
#   3,
#   603,
#   167,
#   497,
#   89,
#   149,
#   71,
#   458,
#   369,
#   458],
#  [199,
#   919,
#   493,
#   528,
#   463,
#   222,
#   529,
#   15,
#   34,
#   920,
#   42,
#   368,
#   36,
#   1071,
#   3,
#   603,
#   167,
#   497,
#   89,
#   149,
#   71,
#   458,
#   369,
#   458],
#  [1347,
#   208,
#   199,
#   241,
#   530,
#   920,
#   42,
#   186,
#   1072,
#   241,
#   282,
#   4,
#   16,
#   353,
#   1,
#   921,
#   12],
#  [1347, 208, 199, 1821, 920, 42, 186, 1072, 241, 282, 4, 16, 353, 1, 921, 12],
#  [1822, 37, 1073, 1074, 454, 283, 7, 51, 157, 153, 110],
#  [20, 5],
#  [228,
#   352,
#   571,
#   335,
#   38,
#   93,
#   117,
#   86,
#   1823,
#   1824,
#   271,
#   13,
#   26,
#   7,
#   194,
#   318,
#   253,
#   3,
#   1825,
#   1075,
#   1826,
#   368,
#   75,
#   571,
#   335,
#   232,
#   192,
#   6,
#   525,
#   810,
#   30,
#   571,
#   335,
#   38,
#   97,
#   61,
#   61,
#   175,
#   88],
#  [566,
#   531,
#   74,
#   23,
#   1827,
#   1348,
#   464,
#   88,
#   37,
#   464,
#   354,
#   1076,
#   531,
#   498,
#   436,
#   86,
#   7,
#   667,
#   1828,
#   464,
#   1077,
#   58,
#   63,
#   318,
#   253],
#  [273,
#   1829,
#   571,
#   335,
#   38,
#   61,
#   571,
#   335,
#   232,
#   441,
#   38,
#   36,
#   234,
#   1830,
#   572,
#   668,
#   571,
#   335,
#   38,
#   7,
#   97,
#   93,
#   93,
#   2,
#   649,
#   1078],
#  [1831, 36, 263, 571, 335, 38, 571, 335, 1832, 335, 38, 1833, 664],
#  [147, 1, 79, 2, 15, 155, 107, 465, 382, 30, 1, 172],
#  [67,
#   65,
#   1834,
#   29,
#   811,
#   145,
#   1835,
#   383,
#   77,
#   150,
#   46,
#   812,
#   736,
#   202,
#   494,
#   1349,
#   13,
#   245,
#   222],
#  [922,
#   612,
#   29,
#   105,
#   382,
#   383,
#   463,
#   495,
#   1836,
#   383,
#   1837,
#   296,
#   5,
#   1838,
#   1839,
#   318,
#   1840,
#   498,
#   120,
#   207,
#   573,
#   1079,
#   613,
#   78,
#   176,
#   29],
#  [226,
#   48,
#   737,
#   147,
#   13,
#   614,
#   497,
#   13,
#   614,
#   8,
#   83,
#   462,
#   1841,
#   1080,
#   381,
#   332,
#   83,
#   669,
#   1842,
#   1081,
#   29,
#   556,
#   83,
#   29,
#   138,
#   86,
#   138,
#   198,
#   6,
#   30,
#   120,
#   150,
#   650,
#   142,
#   670,
#   385,
#   1843,
#   11,
#   41,
#   65,
#   1844,
#   33,
#   1845,
#   124,
#   29,
#   1071,
#   671,
#   7,
#   264,
#   29,
#   211,
#   566],
#  [50, 214, 1846, 923, 560, 41, 11, 4, 115, 25, 382],
#  [11,
#   235,
#   1847,
#   924,
#   48,
#   29,
#   566,
#   409,
#   8,
#   532,
#   83,
#   29,
#   148,
#   91,
#   1848,
#   142,
#   59,
#   1,
#   563,
#   37,
#   210,
#   671,
#   367,
#   386,
#   441,
#   214,
#   8,
#   380,
#   1082,
#   13,
#   8,
#   532,
#   83,
#   24,
#   214,
#   532,
#   83],
#  [352, 199, 241, 11, 184, 97, 2],
#  [273, 1849, 3, 409, 59, 1, 87, 106, 205, 352, 353, 93, 3, 1850, 1083, 1851],
#  [205,
#   4,
#   154,
#   378,
#   165,
#   519,
#   59,
#   1,
#   87,
#   139,
#   151,
#   353,
#   1,
#   925,
#   16,
#   1852,
#   813,
#   286,
#   814,
#   533,
#   68,
#   2,
#   12,
#   336,
#   295,
#   5,
#   324,
#   154,
#   402],
#  [59, 1, 87, 320, 1084, 332, 241, 815, 533, 25, 34, 30, 42],
#  [64,
#   32,
#   353,
#   67,
#   141,
#   1853,
#   231,
#   1,
#   30,
#   2,
#   286,
#   1350,
#   274,
#   139,
#   6,
#   1854,
#   141,
#   32,
#   1855,
#   62,
#   499,
#   40,
#   3,
#   87,
#   1,
#   172,
#   650,
#   138,
#   79,
#   605,
#   353,
#   93,
#   3,
#   574,
#   192,
#   4,
#   125,
#   119,
#   205,
#   153,
#   28,
#   1,
#   93],
#  [352, 353, 60, 93, 117, 59, 1, 1856],
#  [438, 42],
#  [438,
#   64,
#   32,
#   353,
#   50,
#   7,
#   99,
#   1,
#   151,
#   368,
#   811,
#   217,
#   112,
#   1857,
#   318,
#   253,
#   146,
#   236,
#   192],
#  [92,
#   1,
#   273,
#   1858,
#   154,
#   12,
#   466,
#   1859,
#   442,
#   29,
#   72,
#   11,
#   672,
#   3,
#   1860,
#   1861,
#   136,
#   32,
#   284,
#   2,
#   39,
#   437,
#   437,
#   318,
#   253],
#  [78, 168, 1862, 29, 4, 3, 467, 20, 37, 138, 468, 23, 154, 20, 11, 2],
#  [154, 24, 534, 24, 12, 322, 2, 121, 410, 325, 534, 1, 124, 673],
#  [124,
#   1,
#   265,
#   355,
#   913,
#   135,
#   337,
#   926,
#   15,
#   534,
#   34,
#   100,
#   99,
#   12,
#   20,
#   194,
#   79,
#   454,
#   69,
#   355],
#  [30, 24, 33, 5, 29, 77, 500, 674, 10],
#  [139, 83, 1863, 53, 159, 334, 1864],
#  [276,
#   31,
#   180,
#   33,
#   1351,
#   378,
#   29,
#   738,
#   1352,
#   142,
#   815,
#   533,
#   922,
#   29,
#   612,
#   28,
#   117,
#   5,
#   1085,
#   33],
#  [102,
#   2,
#   29,
#   370,
#   320,
#   28,
#   927,
#   1086,
#   282,
#   734,
#   48,
#   575,
#   5,
#   4,
#   29,
#   183,
#   40,
#   411,
#   4,
#   1,
#   927,
#   435,
#   560,
#   1353,
#   206,
#   927,
#   142],
#  [209, 149, 796, 675, 200, 15, 1865, 78, 209, 379],
#  [30, 42, 468, 64, 469, 338, 29, 1, 115, 187, 1866, 1867, 1868],
#  [810,
#   436,
#   576,
#   318,
#   253,
#   192,
#   53,
#   1869,
#   334,
#   48,
#   50,
#   72,
#   2,
#   124,
#   74,
#   1870,
#   69,
#   264,
#   16,
#   113,
#   1],
#  [334,
#   1354,
#   40,
#   214,
#   1355,
#   36,
#   140,
#   8,
#   284,
#   535,
#   470,
#   1871,
#   210,
#   36,
#   440,
#   576,
#   117,
#   458,
#   28,
#   191,
#   90,
#   29,
#   252,
#   1,
#   254,
#   40,
#   231,
#   1,
#   1872,
#   1356],
#  [228,
#   406,
#   29,
#   1,
#   60,
#   145,
#   207,
#   6,
#   352,
#   29,
#   1,
#   60,
#   93,
#   102,
#   459,
#   192,
#   53,
#   59,
#   1,
#   20,
#   197,
#   1357,
#   352,
#   166,
#   300,
#   299,
#   816,
#   1087,
#   456,
#   72,
#   99,
#   62,
#   63,
#   6,
#   60,
#   905,
#   92,
#   1,
#   646],
#  [382,
#   1,
#   263,
#   243,
#   191,
#   90,
#   29,
#   1,
#   1358,
#   4,
#   48,
#   20,
#   733,
#   40,
#   210,
#   339,
#   59,
#   470,
#   1359,
#   470,
#   1360,
#   53,
#   20,
#   274,
#   73,
#   676,
#   20,
#   1873,
#   133,
#   1874,
#   245,
#   145,
#   1875,
#   60,
#   145,
#   98,
#   443,
#   216,
#   412,
#   191,
#   90,
#   29,
#   69,
#   40,
#   1,
#   443,
#   21,
#   300,
#   300,
#   29,
#   86,
#   72,
#   40,
#   1,
#   86,
#   1876,
#   265,
#   1,
#   1088,
#   677,
#   733,
#   4,
#   48,
#   175,
#   1343,
#   1361,
#   1,
#   1089,
#   356,
#   153,
#   28,
#   121,
#   40,
#   246,
#   191,
#   90,
#   29,
#   1],
#  [92,
#   1,
#   176,
#   68,
#   1,
#   296,
#   739,
#   536,
#   300,
#   466,
#   24,
#   678,
#   59,
#   1,
#   87,
#   185,
#   501,
#   412,
#   138,
#   29],
#  [5, 13],
#  [3, 467, 94, 387, 115, 7, 1090, 111, 24, 12, 20, 5],
#  [405,
#   369,
#   1049,
#   127,
#   740,
#   29,
#   1,
#   141,
#   5,
#   40,
#   231,
#   88,
#   817,
#   76,
#   51,
#   183,
#   234,
#   340,
#   382,
#   116,
#   411,
#   36,
#   9,
#   95,
#   577,
#   679,
#   255,
#   214,
#   117,
#   5,
#   1362,
#   413,
#   197,
#   141,
#   100,
#   413,
#   5,
#   369,
#   79,
#   29],
#  [818, 15, 62, 741, 242, 62, 37, 7, 4, 537, 1877, 1878, 29],
#  [377,
#   40,
#   29,
#   59,
#   1,
#   559,
#   4,
#   1879,
#   406,
#   1880,
#   406,
#   7,
#   264,
#   211,
#   110,
#   6,
#   817,
#   211,
#   37,
#   1881,
#   1,
#   355,
#   28,
#   438],
#  [20, 136, 742, 4, 50, 7, 5, 2, 68, 206, 371, 819, 1091, 68, 235, 97, 2],
#  [92, 1, 117, 5, 33, 1092, 247, 1363, 1093, 928, 615],
#  [50, 820],
#  [334,
#   80,
#   529,
#   2,
#   405,
#   1364,
#   458,
#   463,
#   929,
#   77,
#   134,
#   237,
#   41,
#   2,
#   538,
#   186,
#   124,
#   11,
#   5,
#   76,
#   1882,
#   326,
#   930],
#  [502, 186, 4, 33, 441, 81, 30, 42],
#  [20, 274, 73],
#  [742, 739, 242, 40, 24, 42, 162, 230, 121, 410, 372, 1883],
#  [92, 1, 271, 3, 414, 1884, 5, 324, 33, 357, 1885, 246, 230, 497, 931, 1],
#  [352,
#   1,
#   93,
#   192,
#   4,
#   132,
#   1365,
#   1886,
#   217,
#   30,
#   75,
#   525,
#   135,
#   173,
#   503,
#   1094,
#   169,
#   135,
#   175,
#   1,
#   1366],
#  [111, 21, 438],
#  [1,
#   188,
#   39,
#   3,
#   411,
#   1887,
#   6,
#   415,
#   138,
#   45,
#   9,
#   1095,
#   31,
#   237,
#   1096,
#   1095,
#   31,
#   1072,
#   387,
#   308,
#   821,
#   25,
#   9,
#   302,
#   255],
#  [288,
#   31,
#   41,
#   1080,
#   1097,
#   1888,
#   1889,
#   1890,
#   492,
#   1367,
#   320,
#   114,
#   95,
#   90,
#   10,
#   22,
#   578,
#   289,
#   2,
#   23,
#   1070,
#   405,
#   79,
#   73,
#   9,
#   66,
#   7,
#   333,
#   114,
#   372,
#   1368,
#   297,
#   471,
#   822,
#   559,
#   1891,
#   931,
#   149,
#   320,
#   184,
#   1369,
#   373,
#   743,
#   579,
#   461,
#   9,
#   23,
#   932,
#   91,
#   1370,
#   416,
#   50,
#   4,
#   19,
#   157,
#   137,
#   266,
#   58,
#   79,
#   1892],
#  [1, 406, 559, 89, 303, 645, 290, 69, 28],
#  [20, 136, 13, 336, 113, 303, 933, 304, 32, 1098, 320, 494],
#  [823,
#   160,
#   11,
#   4,
#   580,
#   104,
#   651,
#   180,
#   33,
#   277,
#   11,
#   5,
#   824,
#   1325,
#   458,
#   298,
#   1893,
#   192,
#   525],
#  [96, 129, 1099, 26, 20, 5, 30, 42, 581, 616, 1371],
#  [1894,
#   181,
#   934,
#   1372,
#   911,
#   1895,
#   37,
#   523,
#   84,
#   1373,
#   2,
#   388,
#   1100,
#   144,
#   24,
#   927,
#   2,
#   29,
#   5,
#   24,
#   1101,
#   36,
#   13,
#   582,
#   106,
#   71],
#  [1, 1896, 42, 30, 304],
#  [20, 389, 166, 11, 504, 267, 71],
#  [3, 680, 1, 147, 405, 256, 285, 96, 734, 209, 62, 48, 472, 129, 238, 212],
#  [11,
#   235,
#   16,
#   175,
#   1,
#   175,
#   110,
#   1,
#   271,
#   307,
#   1897,
#   1374,
#   53,
#   935,
#   1102,
#   935,
#   12,
#   1898,
#   30,
#   24,
#   70,
#   1103,
#   936,
#   1,
#   26,
#   110,
#   175,
#   132],
#  [96,
#   20,
#   5,
#   12,
#   2,
#   68,
#   403,
#   559,
#   473,
#   44,
#   471,
#   278,
#   9,
#   444,
#   44,
#   474,
#   223,
#   12,
#   20,
#   124,
#   73,
#   341],
#  [382, 4, 378],
#  [372, 1053],
#  [4,
#   937,
#   190,
#   1899,
#   179,
#   197,
#   4,
#   282,
#   226,
#   1900,
#   30,
#   24,
#   434,
#   1901,
#   4,
#   51,
#   151,
#   2,
#   1902],
#  [76, 1, 30, 53, 47, 385, 197, 53],
#  [271,
#   97,
#   120,
#   36,
#   150,
#   1363,
#   2,
#   96,
#   9,
#   53,
#   928,
#   649,
#   4,
#   48,
#   441,
#   110,
#   218,
#   79,
#   69,
#   289,
#   113,
#   1],
#  [103, 73, 582, 1903, 1904, 434, 7, 1375, 324, 244, 358, 128],
#  [1905, 93, 1906, 49, 8, 681, 461],
#  [406, 257, 218, 300, 12, 218, 92],
#  [59,
#   201,
#   257,
#   148,
#   154,
#   573,
#   495,
#   383,
#   115,
#   148,
#   21,
#   184,
#   36,
#   9,
#   744,
#   33,
#   20,
#   258,
#   331,
#   48,
#   183,
#   40,
#   52,
#   193,
#   1,
#   160,
#   124,
#   153,
#   494,
#   253,
#   24,
#   132,
#   525,
#   6,
#   121,
#   157,
#   1104,
#   670,
#   351,
#   176,
#   109],
#  [19,
#   475,
#   1,
#   331,
#   48,
#   92,
#   3,
#   215,
#   177,
#   196,
#   682,
#   3,
#   15,
#   54,
#   1105,
#   1907,
#   34,
#   65,
#   376,
#   154,
#   91,
#   797,
#   503,
#   156,
#   1908,
#   25,
#   50,
#   79,
#   128,
#   66,
#   327,
#   232,
#   50,
#   7,
#   11,
#   51,
#   60,
#   664,
#   1376,
#   15,
#   327,
#   1909,
#   1377,
#   503,
#   1910,
#   35,
#   825,
#   243,
#   60,
#   499,
#   16,
#   503,
#   1911,
#   1,
#   35,
#   539,
#   1378,
#   186,
#   182,
#   40,
#   113,
#   1],
#  [74, 19, 517, 1912, 275, 62, 7, 496, 1, 62],
#  [74, 19, 16, 95, 503, 23, 134, 23, 105, 327, 9, 47, 502, 34, 9, 503, 1913],
#  [92, 68, 124, 608, 1914, 79, 11],
#  [214,
#   184,
#   3,
#   5,
#   116,
#   1915,
#   670,
#   133,
#   493,
#   10,
#   17,
#   84,
#   33,
#   9,
#   46,
#   31,
#   5,
#   1,
#   116],
#  [73,
#   3,
#   75,
#   62,
#   21,
#   160,
#   1379,
#   62,
#   1380,
#   92,
#   59,
#   1,
#   938,
#   196,
#   52,
#   409,
#   305,
#   184,
#   332,
#   65,
#   11,
#   189,
#   410,
#   1916,
#   617,
#   46,
#   501,
#   46,
#   745,
#   939,
#   38,
#   1,
#   141,
#   234,
#   174,
#   1917],
#  [59,
#   1,
#   470,
#   938,
#   826,
#   52,
#   27,
#   618,
#   342,
#   675,
#   1086,
#   1106,
#   805,
#   97,
#   436,
#   74,
#   365,
#   536,
#   610,
#   798,
#   192,
#   53,
#   378,
#   519,
#   192,
#   6,
#   53,
#   540,
#   1918,
#   939],
#  [209, 53, 161, 1, 940, 96, 1919, 152, 13],
#  [915, 10, 17, 53, 1, 1381],
#  [38,
#   274,
#   536,
#   92,
#   60,
#   683,
#   1,
#   89,
#   6,
#   96,
#   76,
#   222,
#   167,
#   827,
#   3,
#   38,
#   941,
#   318,
#   253,
#   226,
#   48,
#   684,
#   34,
#   942,
#   1107,
#   162,
#   34,
#   133,
#   1107,
#   74,
#   5,
#   271,
#   684,
#   1382,
#   133,
#   91,
#   60,
#   210,
#   21,
#   167,
#   827,
#   129,
#   238,
#   2,
#   234,
#   163,
#   286,
#   271,
#   368,
#   194],
#  [359, 32, 66, 328, 132, 50, 271, 85, 432, 34, 438],
#  [30, 24, 434, 265, 105, 1920, 1921, 13, 217],
#  [291, 3, 41, 85, 1922],
#  [574,
#   458,
#   72,
#   11,
#   70,
#   32,
#   70,
#   151,
#   135,
#   454,
#   1108,
#   254,
#   40,
#   76,
#   231,
#   456,
#   1109],
#  [492, 8, 89, 81, 187, 619, 81, 1323, 35, 29, 1, 159, 4, 1923, 222],
#  [381,
#   803,
#   720,
#   4,
#   732,
#   417,
#   191,
#   1110,
#   828,
#   10,
#   202,
#   2,
#   615,
#   160,
#   1111,
#   519,
#   78,
#   95,
#   132,
#   1924,
#   494,
#   253,
#   132,
#   1925,
#   214,
#   1383,
#   1926,
#   169,
#   40,
#   685,
#   332,
#   97,
#   2],
#  [59,
#   1,
#   470,
#   244,
#   309,
#   1384,
#   33,
#   1,
#   106,
#   214,
#   7,
#   1097,
#   72,
#   1927,
#   5,
#   38,
#   108,
#   9,
#   90,
#   2,
#   214,
#   72,
#   104,
#   29,
#   83,
#   829,
#   686,
#   81,
#   1928,
#   34,
#   3,
#   11,
#   182,
#   159,
#   4,
#   117,
#   19,
#   2],
#  [59, 1, 87, 178, 440, 343, 3, 583, 584, 401, 386, 321, 145, 144, 371],
#  [2, 80, 616, 173, 80, 52, 1929, 16, 292, 1930],
#  [1,
#   62,
#   97,
#   830,
#   145,
#   918,
#   445,
#   44,
#   150,
#   1931,
#   1932,
#   102,
#   1933,
#   523,
#   823,
#   332,
#   228,
#   11,
#   297,
#   106,
#   79,
#   1,
#   77,
#   1090,
#   77,
#   831,
#   570,
#   1934,
#   37,
#   410,
#   494],
#  [1, 405, 79, 69, 16, 70, 107, 317, 401, 355, 6, 673],
#  [149,
#   344,
#   1385,
#   44,
#   1935,
#   1936,
#   562,
#   17,
#   1094,
#   24,
#   6,
#   216,
#   1,
#   246,
#   17,
#   455,
#   45,
#   1385,
#   44],
#  [59,
#   1,
#   74,
#   1937,
#   116,
#   4,
#   296,
#   305,
#   5,
#   943,
#   63,
#   1112,
#   515,
#   296,
#   5,
#   1938,
#   22,
#   418,
#   133,
#   41,
#   78,
#   168,
#   446,
#   1386,
#   5,
#   24,
#   465,
#   66,
#   310,
#   47,
#   502,
#   153,
#   289,
#   13,
#   1939],
#  [496,
#   19,
#   48,
#   290,
#   275,
#   19,
#   475,
#   1,
#   59,
#   87,
#   827,
#   1387,
#   1940,
#   13,
#   71,
#   1059,
#   319,
#   68,
#   76,
#   22,
#   79,
#   36,
#   140,
#   8,
#   4,
#   832,
#   746,
#   1388,
#   1,
#   9,
#   70,
#   833,
#   284,
#   41,
#   1389,
#   91,
#   1941,
#   131,
#   69,
#   1390,
#   13,
#   1,
#   40,
#   1391],
#  [92,
#   18,
#   3,
#   87,
#   1,
#   226,
#   26,
#   390,
#   687,
#   242,
#   1392,
#   438,
#   11,
#   1942,
#   40,
#   231,
#   1,
#   1393,
#   6,
#   525,
#   92],
#  [167, 209, 370, 114, 90, 585, 18, 476, 1943, 18],
#  [418,
#   32,
#   44,
#   18,
#   64,
#   32,
#   1,
#   3,
#   251,
#   339,
#   6,
#   50,
#   117,
#   438,
#   67,
#   96,
#   723,
#   17,
#   44,
#   1944,
#   168,
#   7,
#   99,
#   62,
#   275,
#   477,
#   129,
#   1945],
#  [176,
#   109,
#   306,
#   201,
#   65,
#   1394,
#   120,
#   1,
#   352,
#   688,
#   419,
#   118,
#   47,
#   1,
#   93,
#   120,
#   3,
#   89,
#   252,
#   688,
#   419,
#   1946,
#   164,
#   24,
#   420,
#   20,
#   1947,
#   944,
#   111,
#   644,
#   332],
#  [822,
#   168,
#   1,
#   187,
#   62,
#   1113,
#   945,
#   290,
#   275,
#   233,
#   1316,
#   13,
#   438,
#   118,
#   47,
#   1,
#   93,
#   102,
#   154,
#   747,
#   117,
#   5,
#   1948,
#   168,
#   944,
#   2,
#   118,
#   47,
#   36,
#   11,
#   5,
#   118,
#   47,
#   1,
#   1395,
#   2,
#   834],
#  [946,
#   297,
#   224,
#   1949,
#   1,
#   93,
#   1950,
#   122,
#   1114,
#   91,
#   278,
#   495,
#   383,
#   36,
#   102,
#   114,
#   689,
#   7,
#   5,
#   198,
#   1951,
#   620,
#   738,
#   245,
#   169,
#   135,
#   372,
#   1],
#  [24, 564, 156, 47, 234, 432],
#  [206, 150, 46, 436, 576, 564, 156, 11, 143, 140],
#  [102, 177, 6, 947, 5, 1396, 1],
#  [413, 412, 11, 145, 171, 438, 948, 413],
#  [413,
#   352,
#   1952,
#   515,
#   1953,
#   120,
#   206,
#   1954,
#   478,
#   463,
#   495,
#   690,
#   206,
#   150,
#   2,
#   106,
#   109,
#   91,
#   36,
#   412,
#   1955,
#   92,
#   97,
#   40],
#  [406, 287, 1956, 944, 50, 213, 40, 231, 1, 413, 58, 1115, 214, 228, 1957],
#  [413, 271, 228, 12, 36, 114, 577, 1397, 166, 375, 117, 5, 305],
#  [810, 748, 271, 59, 1, 1958, 456, 72, 1116, 447, 458, 74, 282, 149, 1398],
#  [352, 413, 93, 1959, 194, 36, 1960, 1961],
#  [3, 1, 470, 15, 90, 214, 122, 413, 117, 51, 1362, 51, 1399, 2, 1],
#  [413, 296, 5, 1400, 413, 7, 180],
#  [3, 835, 64, 106, 71, 1962, 28],
#  [67, 586, 1, 356, 1117, 376, 356, 1117, 1963, 646],
#  [3,
#   1964,
#   215,
#   309,
#   22,
#   1965,
#   691,
#   161,
#   175,
#   1966,
#   1118,
#   144,
#   360,
#   34,
#   305,
#   836,
#   1119,
#   1967,
#   248,
#   96],
#  [92, 257, 1, 29],
#  [541, 138, 421],
#  [79],
#  [18, 1103, 1401, 1968, 949, 1969],
#  [12],
#  [21,
#   92,
#   331,
#   89,
#   48,
#   499,
#   2,
#   1,
#   352,
#   118,
#   479,
#   47,
#   1,
#   60,
#   3,
#   21,
#   282,
#   557,
#   931,
#   1],
#  [1108, 271, 111, 166, 42, 7, 264, 13, 337, 192, 2, 2, 1970, 1971],
#  [1972,
#   1973,
#   142,
#   505,
#   117,
#   506,
#   8,
#   385,
#   1974,
#   83,
#   241,
#   322,
#   1975,
#   206,
#   150,
#   46,
#   91,
#   1976,
#   296,
#   307,
#   130,
#   83,
#   8,
#   1977],
#  [205, 116, 53, 319, 837, 837, 81, 38, 1978],
#  [5],
#  [459, 566, 87, 1, 535, 1979, 88, 108, 296, 5, 279, 1120, 332, 97, 2],
#  [3,
#   177,
#   196,
#   352,
#   38,
#   117,
#   810,
#   76,
#   94,
#   163,
#   130,
#   1980,
#   11,
#   116,
#   406,
#   378,
#   38],
#  [3,
#   475,
#   1981,
#   621,
#   727,
#   1982,
#   352,
#   38,
#   93,
#   60,
#   3,
#   89,
#   325,
#   38,
#   141,
#   234,
#   1983,
#   13,
#   613,
#   469,
#   573,
#   261,
#   950,
#   81,
#   577,
#   1106,
#   1984,
#   798,
#   192,
#   6,
#   525,
#   97],
#  [38, 111, 1985, 69, 77, 1121, 255, 1402, 692, 79, 2],
#  [13, 62, 201, 116, 16, 134, 134, 53, 693, 244, 1122, 201, 1986],
#  [176,
#   321,
#   83,
#   422,
#   47,
#   142,
#   150,
#   109,
#   65,
#   1987,
#   383,
#   67,
#   92,
#   214,
#   45,
#   60,
#   8,
#   327,
#   542,
#   1123,
#   1403,
#   192],
#  [461, 3, 659, 17, 810, 461, 3, 838, 17],
#  [136,
#   154,
#   421,
#   86,
#   8,
#   1404,
#   474,
#   223,
#   1988,
#   1989,
#   238,
#   1,
#   106,
#   120,
#   150,
#   266,
#   142,
#   210,
#   391,
#   205],
#  [32,
#   89,
#   1,
#   947,
#   11,
#   235,
#   13,
#   7,
#   99,
#   11,
#   951,
#   1990,
#   446,
#   694,
#   749,
#   491,
#   491,
#   1405,
#   1406,
#   610,
#   34,
#   491,
#   5,
#   1991,
#   491,
#   25,
#   52,
#   198,
#   6,
#   150,
#   65,
#   51,
#   211,
#   238,
#   446,
#   183,
#   40,
#   110,
#   142],
#  [136, 1, 461, 1407, 25, 24, 70, 266, 210, 391],
#  [136, 7, 24, 367, 2, 286, 142],
#  [359,
#   455,
#   4,
#   795,
#   1408,
#   526,
#   374,
#   1,
#   65,
#   1992,
#   1993,
#   1994,
#   1995,
#   839,
#   374,
#   799,
#   137,
#   1996,
#   100,
#   1409,
#   133,
#   1124,
#   41,
#   692,
#   27,
#   224,
#   30,
#   1,
#   952,
#   23,
#   903,
#   1410,
#   605,
#   69,
#   2,
#   13],
#  [159, 271, 1997, 722, 1998, 132, 437, 1999, 110],
#  [562, 295, 5, 1, 23, 11, 153, 28],
#  [1,
#   457,
#   316,
#   150,
#   316,
#   1395,
#   374,
#   44,
#   2,
#   403,
#   94,
#   84,
#   567,
#   199,
#   121,
#   28,
#   113,
#   448,
#   110,
#   526,
#   374,
#   97,
#   2,
#   3,
#   526,
#   374,
#   295,
#   5,
#   20,
#   2,
#   374,
#   206,
#   150,
#   316,
#   176,
#   150,
#   316,
#   12,
#   45,
#   403,
#   9,
#   66,
#   44,
#   174,
#   374,
#   154,
#   442,
#   726,
#   8,
#   176,
#   374,
#   44,
#   840,
#   726,
#   30,
#   28,
#   374,
#   1407,
#   45,
#   403,
#   243,
#   5,
#   1,
#   65,
#   611,
#   840,
#   333,
#   114,
#   70,
#   144,
#   22,
#   101,
#   449,
#   921,
#   70],
#  [406],
#  [167, 1331, 1125, 904, 209, 953, 224, 586],
#  [645,
#   1,
#   172,
#   63,
#   164,
#   79,
#   9,
#   358,
#   237,
#   82,
#   587,
#   66,
#   450,
#   445,
#   423,
#   22,
#   18,
#   537,
#   3,
#   953,
#   261,
#   373,
#   120,
#   695,
#   97,
#   110,
#   30,
#   5,
#   462,
#   1126,
#   117,
#   1392,
#   320,
#   3,
#   113,
#   448,
#   310,
#   120,
#   422,
#   841,
#   109,
#   1333,
#   113,
#   1125,
#   174,
#   953,
#   359,
#   101,
#   622,
#   305,
#   1086,
#   165,
#   22,
#   953],
#  [1411, 53, 133, 104, 1412, 167, 572, 46, 53, 236, 7, 55, 2],
#  [187, 623, 28, 750, 53, 954, 15],
#  [218,
#   377,
#   2,
#   337,
#   412,
#   345,
#   751,
#   606,
#   231,
#   53,
#   205,
#   116,
#   751,
#   74,
#   748,
#   5,
#   13,
#   60,
#   3,
#   1127,
#   12,
#   658,
#   345,
#   11,
#   121,
#   151,
#   135,
#   372,
#   1,
#   27,
#   6,
#   51,
#   12,
#   1413],
#  [1128, 26],
#  [69,
#   1129,
#   21,
#   21,
#   1,
#   3,
#   87,
#   535,
#   190,
#   842,
#   1130,
#   564,
#   9,
#   268,
#   842,
#   65,
#   564,
#   42,
#   9,
#   276,
#   527,
#   696,
#   72,
#   1131,
#   610,
#   9,
#   242,
#   206,
#   819,
#   1132,
#   1414,
#   697,
#   91,
#   23,
#   698,
#   75,
#   522,
#   296,
#   105,
#   105,
#   1133],
#  [28, 955, 1, 98, 123, 70, 160, 77, 1134, 843, 604, 25, 918, 568, 390],
#  [699, 356, 1117, 1, 36, 572],
#  [92,
#   29,
#   1135,
#   383,
#   747,
#   216,
#   678,
#   1102,
#   180,
#   383,
#   418,
#   16,
#   346,
#   956,
#   356,
#   1,
#   106,
#   1136,
#   8,
#   1415,
#   1416,
#   161,
#   1137,
#   215,
#   77,
#   151,
#   1417,
#   752,
#   29,
#   52,
#   653,
#   844,
#   209,
#   11,
#   4,
#   167,
#   342,
#   96,
#   36,
#   602,
#   28,
#   700,
#   74,
#   845,
#   29,
#   1418,
#   846,
#   13],
#  [29,
#   916,
#   154,
#   352,
#   29,
#   60,
#   93,
#   3,
#   67,
#   1138,
#   28,
#   19,
#   29,
#   472,
#   20,
#   265,
#   1419,
#   295,
#   271,
#   318,
#   253,
#   59,
#   1,
#   87],
#  [291, 3, 80, 85],
#  [93, 1139, 246, 41, 85, 1140, 291, 3, 80, 85, 41, 303, 116, 75, 432],
#  [291, 3, 80, 85, 41, 85],
#  [288, 79, 847, 11, 588, 1, 152, 139, 251, 67, 472, 34, 4, 408, 1058, 28, 13],
#  [205, 753, 22, 848, 557],
#  [96,
#   489,
#   97,
#   117,
#   175,
#   231,
#   754,
#   507,
#   347,
#   183,
#   11,
#   4,
#   30,
#   11,
#   301,
#   5,
#   347,
#   2,
#   1420,
#   849,
#   238,
#   231,
#   754,
#   263,
#   507,
#   347,
#   507,
#   347,
#   507,
#   347,
#   1420,
#   231,
#   754,
#   507,
#   347,
#   7,
#   97,
#   104,
#   390,
#   66,
#   229,
#   347],
#  [420, 129, 55, 650, 69, 2],
#  [287,
#   98,
#   26,
#   1141,
#   1142,
#   160,
#   2,
#   543,
#   850,
#   141,
#   411,
#   1142,
#   165,
#   7,
#   37,
#   7,
#   1421,
#   78,
#   136,
#   1422,
#   332,
#   83,
#   624,
#   210,
#   5,
#   589,
#   606,
#   210,
#   957,
#   1423,
#   851,
#   157,
#   5,
#   544,
#   326,
#   87,
#   11,
#   5],
#  [321, 321, 321],
#  [205, 331, 385, 1, 2, 1143, 455, 163, 321, 83],
#  [21,
#   79,
#   296,
#   218,
#   45,
#   7,
#   116,
#   530,
#   1397,
#   16,
#   255,
#   293,
#   35,
#   156,
#   91,
#   251,
#   1144,
#   35,
#   37,
#   7,
#   1424,
#   1425,
#   26,
#   71,
#   67,
#   13,
#   701,
#   326,
#   164,
#   334],
#  [32, 1145, 504, 254, 1, 45, 414, 89, 48, 106, 158, 369, 442],
#  [267,
#   71,
#   755,
#   50,
#   458,
#   304,
#   262,
#   490,
#   25,
#   958,
#   5,
#   1426,
#   17,
#   23,
#   731,
#   122,
#   205,
#   153,
#   28],
#  [26, 20, 5, 37, 604, 12, 384, 2],
#  [59,
#   1,
#   87,
#   244,
#   366,
#   479,
#   462,
#   154,
#   153,
#   756,
#   341,
#   9,
#   625,
#   200,
#   466,
#   24,
#   24,
#   1427,
#   442,
#   1427,
#   216,
#   852,
#   245,
#   1,
#   48,
#   451,
#   757,
#   41,
#   97,
#   2,
#   187,
#   1143,
#   209,
#   48,
#   1428,
#   1429,
#   245,
#   222,
#   86,
#   9,
#   113,
#   133,
#   139,
#   153,
#   602,
#   289,
#   1,
#   205],
#  [498,
#   30,
#   42,
#   80,
#   112,
#   42,
#   959,
#   2,
#   4,
#   960,
#   521,
#   109,
#   217,
#   207,
#   1430,
#   86,
#   959,
#   444,
#   8,
#   131,
#   620,
#   35,
#   590,
#   1146,
#   42,
#   1051,
#   590,
#   8,
#   119,
#   101,
#   97,
#   5,
#   1431,
#   758,
#   11,
#   2,
#   185,
#   163,
#   476,
#   494,
#   132,
#   519,
#   113,
#   217,
#   94,
#   169,
#   834,
#   36,
#   9,
#   173,
#   125,
#   56,
#   52,
#   591,
#   361,
#   1432,
#   56,
#   296,
#   592,
#   324,
#   1,
#   494,
#   801,
#   253,
#   1,
#   649,
#   163,
#   72,
#   99,
#   62,
#   7],
#  [143,
#   34,
#   522,
#   362,
#   1433,
#   64,
#   32,
#   461,
#   194,
#   1147,
#   27,
#   126,
#   34,
#   105,
#   522,
#   11,
#   721,
#   961,
#   28],
#  [88,
#   93,
#   698,
#   702,
#   962,
#   72,
#   463,
#   33,
#   7,
#   375,
#   580,
#   190,
#   1148,
#   674,
#   10,
#   531,
#   169,
#   30,
#   42,
#   373,
#   25,
#   305,
#   5,
#   943,
#   351,
#   963,
#   156,
#   478,
#   463,
#   114,
#   130,
#   674,
#   10,
#   964,
#   166,
#   7,
#   36,
#   264,
#   480,
#   626,
#   75,
#   218,
#   354,
#   480,
#   130,
#   324,
#   33,
#   5,
#   106,
#   530,
#   33],
#  [7,
#   99,
#   965,
#   62,
#   72,
#   59,
#   201,
#   87,
#   108,
#   523,
#   219,
#   30,
#   30,
#   42,
#   13,
#   593,
#   71,
#   13,
#   1434,
#   738,
#   320,
#   192],
#  [602, 209, 1, 167, 1435, 400, 1, 940, 28],
#  [1,
#   1365,
#   172,
#   643,
#   725,
#   142,
#   54,
#   77,
#   1436,
#   1097,
#   54,
#   955,
#   147,
#   1149,
#   545,
#   853],
#  [74,
#   647,
#   1437,
#   142,
#   1087,
#   133,
#   54,
#   674,
#   33,
#   9,
#   692,
#   59,
#   1149,
#   172,
#   379,
#   563,
#   320,
#   1438,
#   424,
#   852,
#   441,
#   852,
#   594,
#   5,
#   200,
#   911,
#   2,
#   1,
#   124,
#   67,
#   1439,
#   89,
#   854,
#   48,
#   7,
#   5,
#   168,
#   759],
#  [271, 42, 538, 192, 6, 53],
#  [282, 63, 293],
#  [7, 19, 915, 195, 133, 54, 277, 160, 124],
#  [733, 133, 54, 1436],
#  [13, 62, 1440, 385, 76, 488, 1, 385, 966, 1441, 962, 317, 1140],
#  [847, 133, 1150, 690, 83, 16, 133, 15, 58, 90],
#  [69,
#   264,
#   1,
#   123,
#   1151,
#   451,
#   43,
#   1442,
#   1411,
#   183,
#   4,
#   360,
#   44,
#   588,
#   1128,
#   9,
#   651,
#   53,
#   52,
#   1443,
#   277,
#   731,
#   800,
#   3,
#   1444,
#   422,
#   459],
#  [4, 211, 93, 102, 1445, 1],
#  [32, 137, 18, 93, 242, 13, 62],
#  [18, 159, 21, 4, 434, 91, 153, 28],
#  [288,
#   1,
#   760,
#   344,
#   299,
#   292,
#   53,
#   7,
#   103,
#   722,
#   318,
#   53,
#   341,
#   475,
#   137,
#   15,
#   95,
#   855,
#   681,
#   107,
#   18,
#   72,
#   51,
#   11,
#   292,
#   49,
#   131,
#   25,
#   9,
#   33,
#   1446,
#   179,
#   15,
#   43,
#   11,
#   18,
#   567,
#   14,
#   66,
#   34,
#   99,
#   425,
#   7,
#   333,
#   392,
#   1446,
#   179,
#   341,
#   856,
#   468,
#   318,
#   193,
#   1,
#   253,
#   40],
#  [3, 59, 379, 422, 311, 110, 30, 318, 253, 386, 581, 311, 7, 446],
#  [3,
#   1447,
#   761,
#   89,
#   6,
#   962,
#   499,
#   159,
#   76,
#   252,
#   59,
#   1,
#   87,
#   64,
#   147,
#   299,
#   800,
#   382],
#  [59, 1, 142, 670, 77, 1448, 74, 730],
#  [11, 143, 857, 2],
#  [42, 11, 4, 50, 7, 2],
#  [426,
#   858,
#   4,
#   859,
#   17,
#   165,
#   389,
#   127,
#   47,
#   284,
#   238,
#   1449,
#   858,
#   17,
#   42,
#   806,
#   290,
#   516,
#   1450,
#   16,
#   687],
#  [967,
#   30,
#   207,
#   660,
#   120,
#   967,
#   316,
#   5,
#   89,
#   8,
#   180,
#   33,
#   9,
#   393,
#   653,
#   66,
#   74,
#   21,
#   73,
#   172,
#   7,
#   5,
#   324,
#   269,
#   627,
#   1152,
#   653,
#   967,
#   209,
#   670,
#   671,
#   628,
#   194],
#  [205,
#   187,
#   273,
#   438,
#   67,
#   205,
#   154,
#   120,
#   22,
#   42,
#   650,
#   32,
#   70,
#   36,
#   24,
#   1062,
#   1153,
#   1,
#   1154,
#   3,
#   490,
#   159,
#   20,
#   124],
#  [30, 24, 70],
#  [286, 613, 92, 59, 201, 613, 72, 1155, 97, 16, 1, 192, 6, 525],
#  [102,
#   63,
#   6,
#   40,
#   1156,
#   33,
#   90,
#   623,
#   1451,
#   1157,
#   109,
#   87,
#   6,
#   187,
#   10,
#   83,
#   762,
#   134,
#   230,
#   1452,
#   83],
#  [644, 816, 97, 1453, 36, 102, 703, 183, 1454, 40, 860, 828, 10, 6],
#  [562,
#   1158,
#   97,
#   1455,
#   165,
#   626,
#   294,
#   150,
#   36,
#   102,
#   703,
#   23,
#   20,
#   258,
#   11,
#   4,
#   167,
#   99,
#   211,
#   238],
#  [3,
#   422,
#   405,
#   79,
#   1159,
#   9,
#   362,
#   61,
#   959,
#   23,
#   259,
#   17,
#   88,
#   731,
#   84,
#   70,
#   1456,
#   11,
#   13],
#  [59,
#   1,
#   87,
#   164,
#   438,
#   117,
#   5,
#   1134,
#   23,
#   170,
#   12,
#   1090,
#   63,
#   6,
#   60,
#   3,
#   1,
#   89,
#   4,
#   48,
#   74,
#   580,
#   32,
#   324,
#   1134,
#   968,
#   969],
#  [147, 367, 406, 1, 148, 122, 7, 180, 928, 233, 605, 192, 4, 53],
#  [79,
#   3,
#   87,
#   172,
#   2,
#   1356,
#   902,
#   318,
#   253,
#   40,
#   320,
#   114,
#   70,
#   66,
#   90,
#   17,
#   120,
#   797,
#   3,
#   22,
#   1426,
#   860,
#   17,
#   615,
#   1457,
#   239,
#   22,
#   329],
#  [1, 30, 285],
#  [5, 14, 171, 763, 37, 681, 107, 7, 24, 51, 807],
#  [205,
#   13,
#   62,
#   41,
#   433,
#   1458,
#   1138,
#   51,
#   28,
#   1,
#   41,
#   9,
#   82,
#   423,
#   120,
#   72,
#   11,
#   923,
#   560,
#   495,
#   41,
#   948,
#   18,
#   913,
#   13,
#   303,
#   724,
#   343,
#   110,
#   20,
#   168,
#   86,
#   76,
#   187,
#   753,
#   795,
#   333,
#   4,
#   18,
#   110],
#  [458, 24],
#  [337,
#   803,
#   72,
#   11,
#   41,
#   211,
#   2,
#   1,
#   16,
#   105,
#   41,
#   183,
#   2,
#   7,
#   16,
#   1066,
#   41,
#   37,
#   77,
#   764,
#   1,
#   234,
#   385,
#   151,
#   970,
#   342,
#   378],
#  [605],
#  [861, 76, 72, 363, 213, 21, 5, 40],
#  [205,
#   116,
#   50,
#   233,
#   382,
#   319,
#   76,
#   168,
#   36,
#   102,
#   114,
#   42,
#   191,
#   14,
#   34,
#   65,
#   654,
#   12,
#   28],
#  [562,
#   916,
#   508,
#   320,
#   114,
#   861,
#   34,
#   661,
#   100,
#   107,
#   66,
#   70,
#   861,
#   75,
#   282,
#   21,
#   254,
#   5,
#   112,
#   862,
#   629,
#   293,
#   7,
#   264],
#  [704,
#   29,
#   519,
#   20,
#   176,
#   30,
#   102,
#   15,
#   6,
#   20,
#   124,
#   336,
#   210,
#   98,
#   29,
#   704,
#   1372,
#   282,
#   222,
#   12,
#   7,
#   1455,
#   4,
#   1459],
#  [1160,
#   765,
#   135,
#   128,
#   9,
#   33,
#   147,
#   29,
#   42,
#   763,
#   935,
#   12,
#   766,
#   338,
#   115,
#   184,
#   856,
#   73,
#   657,
#   500],
#  [1,
#   5,
#   18,
#   585,
#   14,
#   1,
#   263,
#   30,
#   24,
#   22,
#   578,
#   46,
#   128,
#   7,
#   84,
#   14,
#   97,
#   1161,
#   856,
#   207,
#   110,
#   344,
#   18,
#   14,
#   30,
#   51,
#   14,
#   1,
#   153,
#   2],
#  [4, 13],
#  [377,
#   40,
#   1,
#   59,
#   563,
#   47,
#   20,
#   440,
#   576,
#   278,
#   162,
#   863,
#   383,
#   65,
#   730,
#   669,
#   83,
#   21,
#   7,
#   410,
#   65,
#   556,
#   67,
#   1083,
#   62,
#   39,
#   1,
#   192,
#   53,
#   368,
#   36,
#   194],
#  [189, 452, 118, 47],
#  [230,
#   6,
#   137,
#   93,
#   206,
#   316,
#   306,
#   176,
#   91,
#   747,
#   745,
#   290,
#   128,
#   33,
#   25,
#   3,
#   448,
#   705,
#   118,
#   47,
#   415,
#   1460,
#   1,
#   68],
#  [3,
#   202,
#   3,
#   767,
#   1461,
#   1,
#   1462,
#   118,
#   50,
#   83,
#   163,
#   768,
#   13,
#   241,
#   1106,
#   142,
#   36,
#   140,
#   669,
#   449,
#   1463,
#   83,
#   368,
#   75,
#   336,
#   241,
#   83,
#   1464,
#   106,
#   12,
#   4,
#   40,
#   1,
#   62,
#   971],
#  [189, 42, 11],
#  [12, 4, 246, 23, 138, 165, 1087, 5, 1465],
#  [331,
#   89,
#   836,
#   50,
#   96,
#   7,
#   51,
#   118,
#   47,
#   1,
#   449,
#   138,
#   805,
#   30,
#   230,
#   804,
#   16,
#   327,
#   232,
#   90,
#   35,
#   555,
#   8,
#   118,
#   5,
#   1,
#   344,
#   367,
#   276,
#   89,
#   769,
#   386,
#   286,
#   274,
#   19],
#  [143, 251, 295, 5, 319, 12, 161, 76, 157, 2],
#  [3,
#   1,
#   409,
#   7,
#   116,
#   305,
#   19,
#   15,
#   44,
#   390,
#   88,
#   7,
#   1466,
#   158,
#   15,
#   444,
#   203,
#   439,
#   25,
#   9,
#   972,
#   243,
#   17,
#   324,
#   477,
#   476,
#   1467,
#   17,
#   1374,
#   442,
#   770,
#   1162,
#   169,
#   40,
#   1,
#   175,
#   208,
#   1163,
#   234,
#   1468],
#  [69,
#   248,
#   330,
#   3,
#   87,
#   680,
#   201,
#   98,
#   372,
#   357,
#   253,
#   1164,
#   361,
#   1469,
#   102,
#   139,
#   546,
#   499,
#   603,
#   139,
#   656,
#   407,
#   106,
#   97,
#   410,
#   565,
#   44,
#   18],
#  [60, 28, 312, 347, 98, 1, 203, 973, 706, 272],
#  [771, 218, 288, 272, 94, 127, 1, 772, 40, 140],
#  [5, 1, 51],
#  [254, 40, 394, 4, 48, 5, 23, 12, 68, 124],
#  [79,
#   11,
#   36,
#   140,
#   78,
#   5,
#   256,
#   132,
#   336,
#   68,
#   165,
#   112,
#   249,
#   15,
#   974,
#   131,
#   35,
#   126,
#   378,
#   161,
#   76,
#   96],
#  [3,
#   9,
#   173,
#   1470,
#   61,
#   56,
#   423,
#   8,
#   17,
#   975,
#   208,
#   65,
#   79,
#   37,
#   460,
#   44,
#   21,
#   77,
#   120,
#   63,
#   728,
#   12,
#   277,
#   44,
#   284,
#   238],
#  [401, 87, 5, 17, 264],
#  [378, 519, 103, 1165, 84],
#  [389, 178, 26, 1059, 1471, 127, 133, 178, 1073, 1074, 24, 51],
#  [406,
#   1,
#   34,
#   54,
#   605,
#   620,
#   128,
#   468,
#   72,
#   459,
#   192,
#   53,
#   235,
#   3,
#   38,
#   108,
#   24,
#   51,
#   1166,
#   2,
#   22,
#   578,
#   16,
#   976,
#   578,
#   225,
#   190,
#   625,
#   279,
#   509,
#   31,
#   354,
#   200,
#   630,
#   1161,
#   114,
#   22,
#   707,
#   30,
#   65,
#   22,
#   403,
#   41,
#   403],
#  [26,
#   288,
#   1,
#   122,
#   41,
#   368,
#   11,
#   301,
#   229,
#   58,
#   285,
#   73,
#   107,
#   631,
#   37,
#   7,
#   51,
#   1167,
#   26,
#   11,
#   107,
#   41,
#   52,
#   46],
#  [117, 189, 26, 71, 27, 6, 229],
#  [505, 3, 506, 665, 211, 168, 16, 735, 227, 2, 543],
#  [382, 72, 11, 96, 169, 146, 22, 94, 212],
#  [16, 609, 561, 81, 38, 148, 864, 244, 2, 43],
#  [63,
#   38,
#   11,
#   334,
#   158,
#   726,
#   414,
#   81,
#   38,
#   137,
#   38,
#   148,
#   68,
#   243,
#   5,
#   203,
#   539,
#   81,
#   38,
#   564,
#   81,
#   38,
#   38,
#   726,
#   564,
#   38],
#  [16,
#   90,
#   133,
#   54,
#   38,
#   108,
#   38,
#   108,
#   573,
#   77,
#   954,
#   957,
#   317,
#   865,
#   977,
#   6,
#   496,
#   207,
#   84,
#   110,
#   130,
#   77,
#   339,
#   207,
#   535,
#   25,
#   77,
#   866,
#   629,
#   725,
#   210,
#   671,
#   63,
#   109,
#   74,
#   671,
#   176,
#   109,
#   25,
#   8,
#   81,
#   148,
#   58,
#   1472,
#   773,
#   33,
#   25,
#   41,
#   1168],
#  [286, 148, 218, 81, 65, 978, 176, 12, 189],
#  [77, 979, 351, 38, 867, 126, 46, 65, 30, 184, 862, 11, 255, 395, 58],
#  [38,
#   365,
#   332,
#   36,
#   59,
#   632,
#   113,
#   303,
#   622,
#   232,
#   33,
#   81,
#   38,
#   25,
#   81,
#   918,
#   445,
#   110,
#   109,
#   145,
#   108,
#   224,
#   12,
#   4,
#   30,
#   210,
#   540,
#   24,
#   124,
#   213,
#   105,
#   92,
#   8,
#   589,
#   606,
#   108,
#   1457,
#   6,
#   673,
#   2],
#  [330,
#   606,
#   81,
#   78,
#   168,
#   427,
#   34,
#   225,
#   108,
#   4,
#   856,
#   427,
#   81,
#   8,
#   120,
#   306,
#   106,
#   323,
#   27,
#   6],
#  [92,
#   38,
#   16,
#   294,
#   980,
#   914,
#   184,
#   232,
#   226,
#   48,
#   480,
#   91,
#   108,
#   7,
#   333,
#   11,
#   235,
#   1,
#   96,
#   77,
#   41,
#   4,
#   12,
#   8,
#   912,
#   1169,
#   1473,
#   1474,
#   81,
#   92,
#   184],
#  [499, 2, 409, 331, 48, 405, 42, 153, 2],
#  [3, 41, 85, 432, 1475, 11, 4, 320, 130, 4, 324, 85, 2, 7, 16, 85, 308, 35],
#  [64, 5, 7, 16, 80, 85, 35, 41],
#  [406, 155, 179, 1170, 328, 178, 595, 12, 36, 1053, 322, 194],
#  [103,
#   162,
#   85,
#   230,
#   351,
#   867,
#   109,
#   52,
#   65,
#   1476,
#   293,
#   274,
#   1477,
#   396,
#   522,
#   67,
#   96,
#   368,
#   36,
#   685,
#   146,
#   184],
#  [103,
#   162,
#   85,
#   230,
#   351,
#   867,
#   109,
#   52,
#   65,
#   1476,
#   293,
#   274,
#   1477,
#   396,
#   522,
#   67,
#   96,
#   368,
#   36,
#   685,
#   146,
#   184],
#  [50,
#   155,
#   179,
#   574,
#   595,
#   178,
#   449,
#   182,
#   291,
#   178,
#   1,
#   276,
#   187,
#   1478,
#   1171,
#   7,
#   157,
#   143,
#   123,
#   155,
#   179,
#   153,
#   289],
#  [50,
#   155,
#   179,
#   574,
#   595,
#   178,
#   449,
#   182,
#   291,
#   178,
#   1,
#   276,
#   187,
#   1478,
#   1171,
#   7,
#   157,
#   143,
#   123,
#   155,
#   179,
#   153,
#   289],
#  [559, 290, 275, 7, 1049, 9, 95, 107, 230, 497, 557],
#  [168, 149, 1398, 36, 510, 404, 108, 97, 75, 539, 178],
#  [20, 136],
#  [1328,
#   1,
#   295,
#   1479,
#   1172,
#   5,
#   404,
#   510,
#   178,
#   536,
#   510,
#   12,
#   20,
#   75,
#   103,
#   3,
#   680,
#   1,
#   382,
#   427,
#   50,
#   404,
#   219,
#   162,
#   7,
#   5,
#   108,
#   94,
#   40,
#   282],
#  [7, 51, 123, 17, 868, 544, 100],
#  [92, 39, 2, 79, 36, 191, 34, 9, 170, 65, 12],
#  [28,
#   18,
#   1173,
#   66,
#   82,
#   216,
#   100,
#   209,
#   70,
#   56,
#   660,
#   18,
#   169,
#   79,
#   78,
#   185,
#   2,
#   76,
#   19,
#   647,
#   134,
#   9,
#   66,
#   82,
#   25,
#   9,
#   981,
#   170,
#   1480,
#   858,
#   8,
#   260,
#   56,
#   428,
#   35,
#   191,
#   34,
#   25,
#   225,
#   18,
#   75,
#   5,
#   347,
#   237,
#   173,
#   708,
#   417,
#   57,
#   55],
#  [1, 547, 407, 619, 1174, 70, 82, 66, 171, 221],
#  [59, 1, 1341, 101, 261, 8, 22, 101, 1157, 439, 183, 15, 80, 9, 101],
#  [147, 18, 79, 184, 36, 8, 56, 633, 35, 208, 78, 559, 836, 240, 820],
#  [288, 285, 403, 595, 11, 439, 456, 147, 113, 1069, 1],
#  [379, 1481, 63, 6],
#  [275, 8, 1482, 1, 982, 89, 982, 462, 956, 379, 28, 47, 905, 346, 7, 182],
#  [1,
#   84,
#   1483,
#   1175,
#   867,
#   497,
#   1076,
#   47,
#   440,
#   290,
#   84,
#   1176,
#   241,
#   25,
#   133,
#   1124,
#   198,
#   166,
#   47,
#   5,
#   313,
#   23,
#   523,
#   334,
#   21,
#   19,
#   271,
#   230,
#   52,
#   261,
#   568],
#  [211, 238, 36, 234, 572, 190, 31, 41, 8, 148, 864],
#  [742, 4, 205, 20, 136],
#  [96,
#   129,
#   541,
#   3,
#   21,
#   154,
#   86,
#   20,
#   15,
#   84,
#   404,
#   65,
#   380,
#   1442,
#   115,
#   194,
#   1177,
#   40,
#   684,
#   115],
#  [1, 271, 158, 136, 2, 26, 136, 1, 336],
#  [1484, 1, 271, 158, 136, 2, 26, 136, 1],
#  [504, 69, 280, 11, 87, 5, 464, 1178, 531, 197],
#  [30, 24, 200],
#  [268,
#   6,
#   60,
#   102,
#   2,
#   29,
#   814,
#   533,
#   6,
#   104,
#   299,
#   316,
#   306,
#   65,
#   463,
#   815,
#   533,
#   11,
#   19,
#   121,
#   99,
#   29,
#   67,
#   629,
#   666,
#   433,
#   2,
#   113,
#   13,
#   21,
#   945,
#   67,
#   416,
#   736,
#   126,
#   176,
#   29,
#   97,
#   1354,
#   86,
#   765,
#   675,
#   113,
#   243,
#   46,
#   7,
#   124,
#   51,
#   866,
#   670,
#   336,
#   30,
#   157,
#   153,
#   289,
#   1],
#  [37, 4, 629, 570, 20, 24, 12, 153, 28],
#  [145, 6, 30, 67, 109, 65, 644, 383],
#  [29,
#   138,
#   121,
#   99,
#   376,
#   11,
#   151,
#   12,
#   654,
#   117,
#   299,
#   387,
#   9,
#   983,
#   344,
#   7,
#   2,
#   387,
#   29,
#   11,
#   1485,
#   29],
#  [755, 3, 1, 823, 50, 3, 767, 1052, 442, 199, 241, 93, 117, 121, 97, 2],
#  [42, 7, 16, 23, 590, 15, 180, 33, 15, 23],
#  [147,
#   79,
#   367,
#   154,
#   540,
#   27,
#   126,
#   146,
#   6,
#   1,
#   189,
#   442,
#   355,
#   673,
#   9,
#   66,
#   450,
#   70,
#   56,
#   402,
#   198,
#   95,
#   107,
#   20,
#   151,
#   376,
#   84,
#   2,
#   175,
#   12,
#   5,
#   369,
#   132,
#   5,
#   2,
#   7,
#   16,
#   534,
#   34,
#   367,
#   314,
#   131,
#   96,
#   178,
#   160,
#   21,
#   34,
#   259,
#   17,
#   176,
#   178,
#   1179,
#   219,
#   154,
#   534,
#   491,
#   58,
#   314,
#   131,
#   534,
#   178,
#   1,
#   7,
#   40,
#   13,
#   21,
#   4],
#  [20, 136, 11, 10, 423, 18, 1371, 30, 24, 124, 76, 326, 615, 355, 28],
#  [24, 41, 84],
#  [521, 5, 29, 67, 1366],
#  [8,
#   46,
#   33,
#   94,
#   802,
#   42,
#   80,
#   217,
#   54,
#   41,
#   451,
#   37,
#   117,
#   5,
#   740,
#   29,
#   80,
#   47,
#   19,
#   80,
#   47],
#  [11, 24, 5, 29, 313, 4, 12, 216, 313, 160, 21, 1424],
#  [288, 29, 233, 300, 117, 5, 745, 387, 180, 33, 983, 115, 188],
#  [29, 74, 111, 20, 440, 55, 115, 1180, 76, 222, 412, 1486, 5, 166],
#  [1, 53, 693, 915, 128, 22, 89, 329],
#  [143, 159, 54, 11, 4, 78, 5, 805, 476, 823, 823, 54, 29, 93],
#  [29, 20, 440, 521, 145, 1487, 161, 1488, 440, 20, 209, 1108],
#  [732,
#   1,
#   7,
#   175,
#   548,
#   187,
#   869,
#   429,
#   48,
#   92,
#   29,
#   658,
#   12,
#   591,
#   300,
#   1181,
#   115,
#   499,
#   65,
#   94,
#   355,
#   245,
#   738,
#   135],
#  [13, 127, 29, 1],
#  [13, 127, 29],
#  [249,
#   1489,
#   1422,
#   467,
#   50,
#   213,
#   5,
#   51,
#   3,
#   68,
#   481,
#   21,
#   319,
#   76,
#   12,
#   147,
#   1182,
#   213,
#   249,
#   76,
#   238,
#   149,
#   215,
#   149,
#   407,
#   46,
#   357,
#   165,
#   64,
#   106,
#   189,
#   71,
#   73,
#   84,
#   20,
#   1490,
#   211,
#   21,
#   377,
#   334,
#   742,
#   5,
#   76,
#   213,
#   213,
#   5,
#   252,
#   179,
#   37,
#   179,
#   1491,
#   86,
#   121,
#   40,
#   16,
#   127,
#   1492,
#   179,
#   35,
#   25,
#   94,
#   908,
#   1493,
#   121,
#   16,
#   237,
#   35],
#  [42, 9, 604, 52, 591, 65, 136],
#  [205,
#   476,
#   924,
#   48,
#   50,
#   984,
#   79,
#   9,
#   58,
#   696,
#   390,
#   687,
#   1092,
#   70,
#   56,
#   870,
#   75,
#   143],
#  [3,
#   409,
#   835,
#   871,
#   92,
#   94,
#   421,
#   50,
#   7,
#   666,
#   985,
#   50,
#   45,
#   7,
#   794,
#   1,
#   19,
#   871,
#   452],
#  [205, 1094, 4, 53, 1],
#  [20,
#   5,
#   468,
#   774,
#   63,
#   317,
#   18,
#   191,
#   289,
#   75,
#   224,
#   9,
#   17,
#   1494,
#   296,
#   13,
#   407,
#   146,
#   519,
#   511,
#   477],
#  [21, 4, 732, 7, 74, 189, 137],
#  [986,
#   13,
#   89,
#   147,
#   275,
#   158,
#   1131,
#   622,
#   33,
#   617,
#   46,
#   850,
#   84,
#   33,
#   502,
#   156,
#   81,
#   65,
#   58,
#   42,
#   186,
#   111,
#   166,
#   11,
#   386,
#   24,
#   757,
#   760,
#   504,
#   165,
#   1183,
#   26,
#   1184,
#   418,
#   1495,
#   121,
#   159,
#   113,
#   1],
#  [30,
#   42,
#   538,
#   186,
#   203,
#   203,
#   872,
#   528,
#   33,
#   134,
#   41,
#   81,
#   156,
#   916,
#   42,
#   32,
#   42,
#   546,
#   84,
#   416,
#   64,
#   418,
#   1496,
#   253,
#   408,
#   83,
#   435,
#   628,
#   318,
#   408,
#   253,
#   499,
#   16,
#   186,
#   52,
#   528,
#   618,
#   451,
#   139,
#   441,
#   528,
#   81,
#   186,
#   174,
#   1148,
#   675,
#   27,
#   6,
#   7,
#   52,
#   33,
#   46,
#   25,
#   203,
#   873,
#   464,
#   504,
#   337,
#   803,
#   19,
#   48],
#  [1, 490, 147, 802, 42, 136, 538, 441, 539, 84],
#  [30, 42, 279, 33, 595, 81],
#  [20, 136],
#  [188,
#   219,
#   12,
#   20,
#   2,
#   474,
#   223,
#   94,
#   6,
#   735,
#   227,
#   63,
#   9,
#   100,
#   244,
#   8,
#   697,
#   35,
#   220,
#   64,
#   1497,
#   614,
#   9,
#   1498,
#   430,
#   1498,
#   974,
#   1368,
#   770,
#   22,
#   283,
#   9,
#   197,
#   1091,
#   357,
#   837,
#   142,
#   709,
#   109,
#   9,
#   503,
#   709,
#   109,
#   12,
#   1185,
#   15,
#   693,
#   342],
#  [15, 90, 27, 6, 176],
#  [705, 643, 9, 387, 308, 65, 74, 300, 2],
#  [59, 1, 3, 415, 98, 74, 300],
#  [1450, 11, 1],
#  [20, 5, 13, 304, 32, 1098],
#  [180, 33, 77, 509, 634, 62],
#  [5, 285, 197, 28],
#  [360,
#   1,
#   2,
#   241,
#   120,
#   109,
#   206,
#   142,
#   1499,
#   478,
#   750,
#   224,
#   104,
#   135,
#   142,
#   210,
#   113,
#   109,
#   206,
#   65,
#   545,
#   224,
#   59,
#   1,
#   168,
#   734,
#   86,
#   24,
#   227,
#   323,
#   2],
#  [189, 273, 987, 53, 771, 1186, 30, 138, 564, 299, 192, 53],
#  [3, 74, 30, 138, 139, 31, 33, 1187, 591, 118, 21, 92],
#  [5,
#   748,
#   594,
#   29,
#   3,
#   380,
#   115,
#   35,
#   257,
#   5,
#   168,
#   51,
#   15,
#   100,
#   277,
#   7,
#   79,
#   36,
#   140,
#   9,
#   371,
#   118,
#   25,
#   8,
#   31,
#   180,
#   33,
#   475,
#   7,
#   15,
#   1500,
#   1501,
#   135,
#   26,
#   874],
#  [30,
#   24,
#   327,
#   505,
#   102,
#   622,
#   1340,
#   327,
#   232,
#   37,
#   7,
#   157,
#   164,
#   79,
#   77,
#   66,
#   76,
#   99,
#   23,
#   1502,
#   140,
#   39,
#   764],
#  [62,
#   65,
#   771,
#   1188,
#   163,
#   99,
#   13,
#   62,
#   359,
#   549,
#   106,
#   71,
#   153,
#   2,
#   154,
#   266,
#   503,
#   424,
#   954],
#  [1503,
#   273,
#   113,
#   987,
#   1,
#   233,
#   79,
#   42,
#   546,
#   257,
#   262,
#   412,
#   166,
#   24,
#   12,
#   108,
#   137,
#   441,
#   37,
#   11,
#   5,
#   751,
#   575,
#   319,
#   76,
#   1,
#   21,
#   68,
#   124,
#   665,
#   2],
#  [505, 3, 460, 381, 128, 10, 130, 115, 211, 3, 46, 46, 130],
#  [3,
#   1,
#   331,
#   19,
#   48,
#   92,
#   257,
#   134,
#   195,
#   10,
#   595,
#   1189,
#   30,
#   24,
#   108,
#   1,
#   46,
#   128,
#   7,
#   24,
#   51,
#   25,
#   152,
#   257,
#   626,
#   108,
#   320,
#   230,
#   7,
#   2,
#   121,
#   685,
#   1189,
#   1,
#   1189,
#   21],
#  [39,
#   201,
#   280,
#   38,
#   38,
#   23,
#   847,
#   94,
#   1133,
#   445,
#   38,
#   296,
#   5,
#   1382,
#   133,
#   596,
#   156],
#  [79, 20, 10, 17, 7, 2],
#  [1327,
#   40,
#   19,
#   48,
#   136,
#   875,
#   107,
#   14,
#   171,
#   430,
#   99,
#   291,
#   34,
#   91,
#   988,
#   12,
#   34,
#   122,
#   320,
#   1438,
#   730,
#   265,
#   142,
#   291,
#   12],
#  [359,
#   96,
#   149,
#   7,
#   5,
#   565,
#   1190,
#   1191,
#   198,
#   1504,
#   1180,
#   831,
#   565,
#   328,
#   132,
#   3,
#   437,
#   1505,
#   989,
#   149,
#   104,
#   119,
#   284,
#   141,
#   16,
#   17,
#   291,
#   3,
#   80,
#   85,
#   34,
#   1,
#   24,
#   292,
#   34,
#   16,
#   131,
#   560,
#   610,
#   1399,
#   328,
#   235,
#   97,
#   16,
#   131,
#   560,
#   291,
#   34,
#   397,
#   1139,
#   78,
#   16,
#   131,
#   30,
#   550,
#   989,
#   1473,
#   1506,
#   565,
#   328,
#   132,
#   143,
#   549,
#   194,
#   291,
#   849,
#   235,
#   460,
#   468,
#   141,
#   92,
#   668,
#   89,
#   328,
#   26,
#   291,
#   34,
#   16,
#   314,
#   82,
#   120,
#   227,
#   15,
#   41,
#   100,
#   579,
#   482,
#   110,
#   411,
#   109,
#   15,
#   101,
#   51,
#   848,
#   22,
#   630,
#   109,
#   78,
#   15,
#   70,
#   84,
#   101,
#   100,
#   156,
#   1192,
#   1193],
#  [143],
#  [136, 1, 147, 79],
#  [166, 432, 11, 79, 34, 9, 42, 21, 42, 29, 318, 350, 134, 305, 246, 103],
#  [50,
#   7,
#   32,
#   365,
#   256,
#   364,
#   11,
#   2,
#   7,
#   113,
#   364,
#   13,
#   105,
#   131,
#   13,
#   105,
#   31,
#   101,
#   7,
#   16,
#   125,
#   398,
#   524],
#  [21,
#   216,
#   592,
#   14,
#   92,
#   8,
#   125,
#   398,
#   326,
#   346,
#   12,
#   94,
#   466,
#   183,
#   40,
#   315,
#   524,
#   160,
#   116,
#   14,
#   394,
#   4,
#   48,
#   21,
#   50,
#   7,
#   32,
#   20],
#  [117, 1353],
#  [566,
#   59,
#   1,
#   563,
#   44,
#   65,
#   230,
#   34,
#   365,
#   104,
#   135,
#   142,
#   206,
#   731,
#   113,
#   150,
#   44,
#   1507,
#   811,
#   417,
#   1194,
#   34,
#   756,
#   282,
#   169,
#   252,
#   451,
#   53,
#   27,
#   6],
#  [1,
#   39,
#   159,
#   4,
#   349,
#   13,
#   88,
#   190,
#   46,
#   70,
#   1508,
#   30,
#   24,
#   25,
#   15,
#   70,
#   177,
#   17,
#   68,
#   70,
#   134,
#   948,
#   151,
#   738,
#   476,
#   132,
#   649,
#   649],
#  [27, 6, 247, 34, 2, 1195, 25, 9, 302, 229, 99, 95, 12],
#  [3,
#   1136,
#   7,
#   264,
#   3,
#   30,
#   35,
#   41,
#   9,
#   95,
#   31,
#   44,
#   1509,
#   44,
#   22,
#   101,
#   909,
#   31,
#   44,
#   473,
#   223,
#   9,
#   23,
#   10,
#   774,
#   18,
#   597,
#   97,
#   16,
#   17,
#   161,
#   833,
#   44,
#   576],
#  [205, 1510, 68, 48, 11, 272, 763, 158, 40, 208],
#  [370,
#   15,
#   41,
#   44,
#   18,
#   99,
#   18,
#   935,
#   11,
#   775,
#   16,
#   1511,
#   1196,
#   710,
#   18,
#   44,
#   120,
#   16,
#   175,
#   17],
#  [370, 242, 62, 12, 1449, 103, 53, 514, 140, 190, 22, 101, 7, 51, 807, 289],
#  [59, 1, 87, 106, 214, 148, 5, 1512, 214, 15, 95, 41, 225, 65, 198, 506, 11],
#  [705, 189, 400, 470, 201, 214, 24, 122, 114, 453, 90, 990],
#  [88,
#   412,
#   413,
#   214,
#   405,
#   412,
#   570,
#   7,
#   463,
#   110,
#   876,
#   91,
#   435,
#   142,
#   1176,
#   748,
#   111,
#   413,
#   463,
#   120],
#  [102, 339, 78, 5],
#  [3,
#   265,
#   26,
#   1184,
#   164,
#   92,
#   1513,
#   12,
#   257,
#   69,
#   77,
#   100,
#   255,
#   114,
#   125,
#   450,
#   345,
#   395,
#   254,
#   2,
#   1,
#   87,
#   1197,
#   115,
#   4,
#   12,
#   72,
#   11],
#  [59, 1, 172, 84, 364, 12, 5, 29, 257, 157, 153, 2],
#  [92,
#   154,
#   112,
#   210,
#   109,
#   112,
#   68,
#   364,
#   12,
#   77,
#   76,
#   9,
#   86,
#   479,
#   112,
#   364,
#   12,
#   112,
#   100,
#   2],
#  [197,
#   100,
#   29,
#   197,
#   371,
#   364,
#   133,
#   75,
#   401,
#   250,
#   39,
#   1155,
#   321,
#   83,
#   400,
#   145,
#   201,
#   29],
#  [1, 159, 87, 5, 13, 364, 257],
#  [309,
#   689,
#   227,
#   74,
#   30,
#   138,
#   904,
#   148,
#   1495,
#   257,
#   433,
#   816,
#   166,
#   40,
#   1,
#   454,
#   1,
#   226,
#   1154,
#   78,
#   5,
#   1,
#   24,
#   227,
#   25,
#   102,
#   387,
#   308,
#   991,
#   91,
#   46,
#   257,
#   1198,
#   992,
#   83,
#   2,
#   68,
#   257,
#   254,
#   40,
#   252,
#   30,
#   334,
#   282,
#   257,
#   1514,
#   308,
#   364,
#   415,
#   1190,
#   273,
#   89,
#   297,
#   1,
#   218,
#   39,
#   104,
#   341,
#   411,
#   76,
#   4,
#   15],
#  [11, 5, 324, 647, 1056, 236, 272, 27, 6, 7, 16, 175, 208, 183, 615],
#  [193, 26, 92, 18, 466, 76, 221, 251],
#  [290,
#   128,
#   33,
#   1199,
#   47,
#   7,
#   5,
#   589,
#   606,
#   118,
#   233,
#   42,
#   8,
#   310,
#   180,
#   33,
#   47,
#   221],
#  [19,
#   596,
#   562,
#   67,
#   724,
#   13,
#   238,
#   776,
#   1,
#   993,
#   84,
#   596,
#   130,
#   853,
#   139,
#   29,
#   456,
#   1138,
#   558,
#   1164,
#   1,
#   163,
#   558,
#   1515,
#   551,
#   30,
#   24,
#   711,
#   53,
#   1516,
#   130,
#   1107,
#   130,
#   13,
#   83,
#   112,
#   108,
#   596,
#   294,
#   994,
#   75,
#   128,
#   385,
#   27,
#   6,
#   437],
#  [3,
#   87,
#   436,
#   1,
#   244,
#   9,
#   13,
#   512,
#   255,
#   130,
#   457,
#   39,
#   968,
#   592,
#   212,
#   38,
#   130,
#   5,
#   108,
#   11,
#   134,
#   763,
#   777,
#   202,
#   995,
#   877,
#   996,
#   38,
#   108,
#   130],
#  [152, 255, 395, 81, 38, 100, 1, 21, 12, 108, 4, 2, 114, 100],
#  [21,
#   92,
#   331,
#   429,
#   48,
#   153,
#   2,
#   130,
#   605,
#   36,
#   114,
#   100,
#   20,
#   436,
#   163,
#   190,
#   108,
#   1,
#   1,
#   27,
#   38,
#   2,
#   386,
#   274,
#   31,
#   186,
#   165,
#   108,
#   21,
#   122,
#   31,
#   74,
#   8,
#   252,
#   427,
#   81,
#   75,
#   12,
# ...
#  [42, 138, 28],
#  [3,
#   29,
#   339,
#   63,
#   6,
#   42,
#   24,
#   33,
#   268,
#   6,
#   520,
#   51,
#   104,
#   31,
#   33,
#   104,
#   424,
#   1288,
#   99,
#   95,
#   11,
#   39,
#   29,
#   2,
#   4,
#   134,
#   90,
#   104,
#   464,
#   568,
#   64,
#   127,
#   518],
#  [74, 73],
#  [206,
#   142,
#   94,
#   377,
#   745,
#   47,
#   468,
#   1656,
#   690,
#   216,
#   447,
#   209,
#   13,
#   1656,
#   690,
#   73,
#   15,
#   41,
#   1657,
#   386,
#   161,
#   15,
#   23,
#   42,
#   47,
#   1030,
#   118,
#   47,
#   12,
#   266,
#   64,
#   511,
#   294,
#   6,
#   4,
#   47,
#   5,
#   138,
#   1118,
#   88,
#   676,
#   42,
#   47,
#   1160,
#   234,
#   142,
#   11,
#   375,
#   138],
#  [151,
#   118,
#   47,
#   1,
#   3,
#   648,
#   57,
#   622,
#   33,
#   31,
#   33,
#   9,
#   31,
#   180,
#   33,
#   1218,
#   145,
#   171,
#   8,
#   647,
#   424,
#   227,
#   809,
#   227,
#   47,
#   206,
#   109,
#   176,
#   460,
#   479,
#   1236,
#   78,
#   15,
#   479],
#  [19,
#   1,
#   25,
#   1007,
#   769,
#   987,
#   8,
#   310,
#   33,
#   118,
#   21,
#   1658,
#   8,
#   276,
#   118,
#   9,
#   302,
#   255,
#   8,
#   310,
#   424,
#   227,
#   47,
#   224,
#   316,
#   338,
#   1227,
#   265,
#   150,
#   176,
#   27,
#   6,
#   183,
#   15,
#   145,
#   171,
#   286,
#   20,
#   234,
#   290,
#   412,
#   7,
#   71],
#  [19,
#   1,
#   25,
#   1007,
#   769,
#   987,
#   8,
#   310,
#   33,
#   118,
#   21,
#   1658,
#   8,
#   276,
#   118,
#   9,
#   302,
#   255,
#   8,
#   310,
#   424,
#   227,
#   35,
#   47,
#   224,
#   316,
#   338,
#   1227,
#   265,
#   150,
#   176,
#   27,
#   6,
#   183,
#   15,
#   145,
#   171,
#   286,
#   20,
#   234,
#   290,
#   412,
#   7,
#   71],
#  [521, 344, 118, 479, 47],
#  [20, 57, 88],
#  [203,
#   166,
#   12,
#   265,
#   207,
#   207,
#   6,
#   110,
#   1030,
#   118,
#   47,
#   1,
#   108,
#   804,
#   47,
#   74,
#   23,
#   122,
#   140,
#   1114,
#   893,
#   2,
#   764,
#   145,
#   725],
#  [1031,
#   118,
#   1096,
#   73,
#   25,
#   9,
#   387,
#   308,
#   240,
#   1,
#   2,
#   13,
#   637,
#   555,
#   828,
#   758,
#   1527,
#   141],
#  [862, 37, 24, 33, 11],
#  [206,
#   323,
#   13,
#   1063,
#   8,
#   1659,
#   257,
#   35,
#   479,
#   182,
#   12,
#   36,
#   140,
#   83,
#   1346,
#   1216,
#   1135,
#   162,
#   112,
#   795,
#   556,
#   27,
#   6,
#   123,
#   1659,
#   257],
#  [193,
#   26,
#   32,
#   47,
#   518,
#   1660,
#   445,
#   46,
#   532,
#   122,
#   23,
#   134,
#   1432,
#   7,
#   496,
#   62,
#   37,
#   31,
#   33,
#   24,
#   52,
#   135,
#   1085,
#   58,
#   47,
#   548],
#  [1486,
#   1,
#   13,
#   624,
#   355,
#   1661,
#   550,
#   202,
#   652,
#   1,
#   1657,
#   11,
#   624,
#   3,
#   241,
#   415,
#   9,
#   1514,
#   308,
#   46,
#   415,
#   236,
#   484],
#  [19, 1662],
#  [8, 35, 555, 907, 395, 255, 45, 860, 138],
#  [12,
#   188,
#   5,
#   297,
#   492,
#   116,
#   75,
#   690,
#   224,
#   370,
#   62,
#   35,
#   273,
#   582,
#   471,
#   145,
#   139,
#   778,
#   241,
#   747,
#   91,
#   175,
#   481],
#  [5,
#   42,
#   118,
#   47,
#   188,
#   543,
#   1,
#   13,
#   60,
#   28,
#   98,
#   1,
#   263,
#   31,
#   33,
#   112,
#   65,
#   105,
#   42],
#  [65,
#   63,
#   653,
#   173,
#   142,
#   191,
#   138,
#   210,
#   21,
#   1200,
#   480,
#   13,
#   83,
#   476,
#   120,
#   118,
#   47,
#   118,
#   47,
#   616,
#   71,
#   24,
#   19,
#   12,
#   158,
#   52,
#   135,
#   33,
#   31,
#   180,
#   31,
#   54,
#   309,
#   689,
#   227,
#   20,
#   555,
#   8,
#   90,
#   104,
#   134,
#   12,
#   511,
#   608,
#   241,
#   47,
#   78,
#   168,
#   611,
#   1348,
#   118,
#   133,
#   156,
#   1663,
#   96,
#   20,
#   118,
#   925,
#   1522,
#   42,
#   7,
#   400,
#   1,
#   33,
#   6,
#   241,
#   207,
#   109,
#   472,
#   210,
#   1228,
#   7,
#   1643,
#   317,
#   30,
#   903,
#   1518,
#   903,
#   46,
#   532,
#   469,
#   7,
#   683,
#   307,
#   967,
#   109,
#   7,
#   5,
#   816,
#   32,
#   169,
#   135,
#   268,
#   568],
#  [67,
#   21,
#   288,
#   118,
#   47,
#   53,
#   102,
#   13,
#   221,
#   211,
#   168,
#   637,
#   73,
#   213,
#   5,
#   338,
#   241,
#   346],
#  [63,
#   6,
#   3,
#   812,
#   55,
#   1289,
#   55,
#   3,
#   9,
#   46,
#   855,
#   118,
#   10,
#   616,
#   197,
#   2,
#   36,
#   138,
#   1070,
#   32,
#   391],
#  [4, 137, 60, 93, 3],
#  [3, 1290, 83, 145, 207, 47, 83, 148, 4, 39, 240],
#  [309,
#   689,
#   227,
#   358,
#   973,
#   2,
#   1,
#   717,
#   37,
#   3,
#   1517,
#   25,
#   20,
#   555,
#   246,
#   363,
#   73,
#   4,
#   1,
#   27,
#   6,
#   121,
#   2,
#   53,
#   1664],
#  [4,
#   1,
#   39,
#   250,
#   9,
#   839,
#   697,
#   61,
#   56,
#   66,
#   229,
#   8,
#   272,
#   513,
#   208,
#   10,
#   17,
#   20,
#   2,
#   482,
#   20,
#   185,
#   122,
#   9,
#   279,
#   174,
#   883,
#   1237,
#   170,
#   69,
#   2],
#  [209, 48, 1037, 73, 116, 159, 880, 48, 1, 443, 706, 3, 55],
#  [45,
#   172,
#   5,
#   716,
#   44,
#   18,
#   1508,
#   58,
#   119,
#   23,
#   263,
#   312,
#   18,
#   27,
#   6,
#   121,
#   16,
#   307,
#   239,
#   119,
#   86,
#   52,
#   135,
#   44],
#  [3,
#   46,
#   1,
#   719,
#   409,
#   683,
#   517,
#   43,
#   10,
#   8,
#   173,
#   708,
#   8,
#   1634,
#   128,
#   272,
#   64,
#   71,
#   18,
#   209,
#   1551,
#   149,
#   5,
#   1043,
#   18,
#   25,
#   37,
#   18,
#   122,
#   84,
#   44,
#   41,
#   1120,
#   161,
#   513,
#   208,
#   272,
#   183],
#  [574,
#   517,
#   43,
#   10,
#   15,
#   302,
#   1027,
#   34,
#   21,
#   12,
#   25,
#   9,
#   259,
#   17,
#   272,
#   23,
#   79,
#   16,
#   1665,
#   44,
#   13,
#   303,
#   933,
#   23,
#   105,
#   101,
#   399,
#   18],
#  [181,
#   330,
#   59,
#   1,
#   87,
#   27,
#   6,
#   7,
#   247,
#   128,
#   199,
#   46,
#   128,
#   44,
#   36,
#   129,
#   212,
#   146,
#   187,
#   698,
#   27,
#   126,
#   719],
#  [26, 127, 469, 363, 175, 17, 272, 773, 12],
#  [3,
#   431,
#   57,
#   23,
#   58,
#   140,
#   366,
#   444,
#   482,
#   8,
#   225,
#   18,
#   18,
#   68,
#   17,
#   5,
#   13,
#   482,
#   225,
#   88,
#   521,
#   21,
#   990,
#   544,
#   9,
#   23,
#   58,
#   1613,
#   73,
#   242,
#   23,
#   425,
#   917,
#   1113,
#   839,
#   499,
#   94,
#   288,
#   449,
#   445,
#   719,
#   378,
#   69,
#   169,
#   28],
#  [64,
#   55,
#   37,
#   72,
#   16,
#   95,
#   46,
#   239,
#   119,
#   88,
#   349,
#   114,
#   697,
#   435,
#   560,
#   47,
#   357,
#   1051,
#   203,
#   1165,
#   75,
#   4,
#   17],
#  [3, 422, 4, 1666, 50, 62, 48, 7, 51, 549, 55],
#  [101,
#   188,
#   551,
#   5,
#   716,
#   44,
#   18,
#   312,
#   389,
#   18,
#   695,
#   2,
#   27,
#   6,
#   247,
#   199,
#   52,
#   135,
#   44,
#   2],
#  [147, 58, 111, 278, 18, 1277, 159, 103, 3, 130, 18],
#  [9, 23, 36, 5, 312],
#  [18,
#   245,
#   73,
#   26,
#   57,
#   7,
#   2,
#   7,
#   16,
#   307,
#   239,
#   402,
#   57,
#   451,
#   134,
#   41,
#   2,
#   482,
#   1,
#   201,
#   3,
#   122,
#   154,
#   620,
#   72,
#   433,
#   11,
#   41,
#   18,
#   2,
#   16,
#   625,
#   134,
#   31,
#   41,
#   202,
#   77,
#   23,
#   482,
#   35,
#   1355,
#   620],
#  [8, 688, 419, 1575, 41, 2, 688, 419, 416, 25, 8, 90, 272, 45, 122, 130],
#  [226,
#   48,
#   471,
#   51,
#   222,
#   795,
#   3,
#   18,
#   64,
#   177,
#   196,
#   55,
#   87,
#   18,
#   69,
#   792,
#   267,
#   1247,
#   1119],
#  [45, 304, 262, 57, 667, 65, 486, 18, 62],
#  [11,
#   5,
#   1016,
#   312,
#   252,
#   112,
#   39,
#   4,
#   133,
#   491,
#   44,
#   551,
#   1213,
#   63,
#   1291,
#   112,
#   1600,
#   1567,
#   112,
#   1202,
#   831,
#   895,
#   119,
#   112,
#   9,
#   51,
#   1002,
#   119,
#   12,
#   31,
#   439,
#   1619,
#   100,
#   119,
#   112,
#   1210,
#   82,
#   18,
#   481,
#   139,
#   487,
#   200,
#   165,
#   44,
#   128,
#   112,
#   9,
#   17,
#   165,
#   43,
#   10,
#   152,
#   117,
#   4,
#   77,
#   747,
#   47,
#   112,
#   887],
#  [655,
#   62,
#   20,
#   545,
#   274,
#   233,
#   5,
#   297,
#   106,
#   157,
#   1533,
#   69,
#   2,
#   64,
#   21,
#   212,
#   37,
#   168,
#   222,
#   1163,
#   57,
#   301],
#  [585, 835],
#  [188, 27, 6, 169, 15, 58, 107, 99, 12],
#  [26, 11, 16, 402, 105, 44, 71, 140, 59, 1, 87, 183, 40, 208, 27, 6],
#  [270,
#   17,
#   31,
#   746,
#   16,
#   208,
#   17,
#   56,
#   633,
#   78,
#   5,
#   723,
#   17,
#   15,
#   1035,
#   1027,
#   34,
#   981,
#   170,
#   237,
#   131,
#   91,
#   240],
#  [3, 18, 9, 31, 120, 170, 527, 170, 879, 26, 1292],
#  [476,
#   1,
#   2,
#   680,
#   201,
#   254,
#   2,
#   58,
#   717,
#   1667,
#   199,
#   158,
#   733,
#   8,
#   41,
#   134,
#   482,
#   7,
#   3,
#   18,
#   36,
#   1468,
#   511,
#   246,
#   17,
#   18,
#   1,
#   20,
#   16,
#   1561,
#   152,
#   13,
#   26,
#   1184,
#   160,
#   5,
#   247,
#   1,
#   4,
#   106,
#   949,
#   104,
#   82,
#   390,
#   444,
#   31,
#   101,
#   18,
#   223,
#   709,
#   109,
#   9,
#   44,
#   408,
#   101,
#   465,
#   708,
#   709,
#   113,
#   109,
#   44,
#   224,
#   225,
#   18,
#   509,
#   22,
#   101,
#   279,
#   31,
#   9,
#   197,
#   950,
#   1562,
#   1668,
#   90,
#   272,
#   1194,
#   950,
#   1669,
#   17,
#   1621,
#   647,
#   9,
#   197,
#   44,
#   120,
#   15,
#   70,
#   16,
#   43,
#   10,
#   320,
#   45,
#   18,
#   58,
#   717,
#   249,
#   780,
#   47,
#   357,
#   4],
#  [45, 39, 309, 369, 873, 464, 43, 10, 69, 2, 23, 151, 207, 30, 130],
#  [164, 4, 122],
#  [18,
#   486,
#   7,
#   69,
#   2,
#   8,
#   31,
#   259,
#   208,
#   35,
#   1293,
#   9,
#   134,
#   41,
#   156,
#   9,
#   90,
#   844,
#   9,
#   113,
#   31,
#   208,
#   17,
#   18,
#   285,
#   433,
#   15,
#   70,
#   1,
#   344,
#   25,
#   7,
#   69,
#   15,
#   43,
#   10,
#   102,
#   18,
#   114,
#   43,
#   10,
#   24,
#   51],
#  [218, 4, 273, 48, 285, 278, 242, 19, 323, 52, 434, 1223, 121, 69, 338, 1],
#  [4, 896, 132, 343, 344, 8, 307, 641, 125, 119, 9, 1294, 34, 28],
#  [360,
#   1,
#   148,
#   365,
#   9,
#   146,
#   473,
#   44,
#   37,
#   146,
#   473,
#   44,
#   771,
#   346,
#   213,
#   40,
#   44,
#   428,
#   225],
#  [9, 590, 237, 887, 213, 315, 44, 27, 6, 238, 374, 21, 1245],
#  [1489, 88, 57, 465, 7, 52, 128, 46, 25, 764, 1664, 524, 465],
#  [45, 218, 39, 3, 330, 720, 19, 554, 126],
#  [843, 144, 1239, 19],
#  [660,
#   498,
#   1,
#   161,
#   360,
#   9,
#   641,
#   761,
#   445,
#   46,
#   481,
#   310,
#   509,
#   362,
#   707,
#   316,
#   417,
#   340,
#   193,
#   1609,
#   230,
#   992,
#   1670,
#   1670],
#  [2, 170, 1144, 91, 18, 417, 45],
#  [242,
#   4,
#   629,
#   1,
#   124,
#   312,
#   18,
#   1257,
#   656,
#   8,
#   307,
#   239,
#   125,
#   119,
#   270,
#   272,
#   239,
#   44,
#   288,
#   444,
#   390,
#   18,
#   165,
#   9,
#   66,
#   171,
#   23,
#   220,
#   171,
#   25,
#   8,
#   31,
#   111,
#   10,
#   31,
#   193,
#   90,
#   23,
#   1443,
#   2,
#   18,
#   89,
#   6,
#   361,
#   24,
#   1],
#  [3,
#   18,
#   193,
#   26,
#   55,
#   39,
#   3,
#   665,
#   2,
#   599,
#   37,
#   349,
#   104,
#   23,
#   17,
#   513,
#   208,
#   32,
#   17],
#  [60,
#   28,
#   821,
#   98,
#   64,
#   32,
#   30,
#   808,
#   15,
#   95,
#   134,
#   41,
#   390,
#   82,
#   156,
#   2,
#   482,
#   1254,
#   122,
#   18,
#   78,
#   332,
#   95,
#   83,
#   95,
#   607,
#   326,
#   929],
#  [103, 267, 1295],
#  [26, 55, 9, 641, 402, 98, 372, 106, 161, 27, 6, 15, 4],
#  [1671, 71, 267, 322, 36, 40, 21, 4, 140, 427, 140],
#  [9, 846, 191, 34, 95, 31, 208, 22, 101, 99, 425, 254, 249],
#  [164,
#   4,
#   1,
#   3,
#   286,
#   1041,
#   125,
#   398,
#   134,
#   439,
#   1293,
#   43,
#   10,
#   793,
#   90,
#   692,
#   7,
#   2,
#   15,
#   270,
#   17,
#   6,
#   20,
#   37,
#   716,
#   84,
#   117,
#   51,
#   27,
#   126,
#   1668],
#  [3,
#   1,
#   897,
#   50,
#   4,
#   12,
#   309,
#   31,
#   111,
#   10,
#   441,
#   90,
#   165,
#   465,
#   9,
#   66,
#   245,
#   23,
#   678,
#   70,
#   67,
#   472,
#   8,
#   175,
#   17,
#   35,
#   272,
#   1665,
#   44,
#   27,
#   6,
#   2,
#   67,
#   169,
#   15,
#   411,
#   789,
#   170,
#   237,
#   375,
#   86,
#   181,
#   604,
#   338],
#  [4, 1285, 398, 9, 155, 314, 131, 68, 457, 6],
#  [661, 267, 228, 55, 1268, 44, 18],
#  [18, 45, 242, 62, 24, 124, 147, 808, 391, 3, 714, 2],
#  [655,
#   62,
#   350,
#   434,
#   1223,
#   323,
#   183,
#   152,
#   18,
#   722,
#   1172,
#   252,
#   53,
#   72,
#   1193,
#   1672,
#   280,
#   1,
#   97,
#   50,
#   1553,
#   236,
#   1673,
#   488,
#   112],
#  [201,
#   251,
#   37,
#   1674,
#   7,
#   2,
#   48,
#   4,
#   1,
#   460,
#   1037,
#   370,
#   26,
#   152,
#   147,
#   30,
#   1674,
#   77,
#   388,
#   947],
#  [1,
#   7,
#   69,
#   2,
#   3,
#   57,
#   8,
#   125,
#   398,
#   329,
#   259,
#   513,
#   208,
#   17,
#   35,
#   1293,
#   187,
#   429,
#   48,
#   26],
#  [2,
#   388,
#   391,
#   190,
#   125,
#   398,
#   1027,
#   34,
#   679,
#   14,
#   171,
#   66,
#   1044,
#   314,
#   131,
#   842,
#   362,
#   80,
#   270,
#   842,
#   1041,
#   328,
#   259,
#   17,
#   9,
#   1675,
#   317,
#   78,
#   77,
#   41,
#   1187,
#   529,
#   80,
#   112,
#   44,
#   585,
#   896,
#   132,
#   19,
#   80,
#   47],
#  [3, 124, 1676, 337, 181, 2, 15, 95, 107],
#  [267, 32, 1, 64, 521, 908, 370, 2, 196, 124],
#  [3, 18, 431, 26, 55, 69, 104, 874, 2, 236],
#  [187, 224, 28, 215, 431, 8, 155, 199, 73, 125, 119, 74, 4],
#  [4, 298, 50, 7, 266, 23, 105, 17],
#  [3,
#   18,
#   215,
#   177,
#   196,
#   394,
#   48,
#   535,
#   64,
#   136,
#   18,
#   55,
#   13,
#   64,
#   136,
#   18,
#   32,
#   18,
#   50,
#   18,
#   21,
#   4,
#   7,
#   1622,
#   194,
#   64,
#   106,
#   143,
#   7,
#   194,
#   57,
#   3,
#   16,
#   239,
#   402,
#   167,
#   1146,
#   239,
#   7,
#   84],
#  [188, 1, 201, 39, 400, 323, 772, 1, 342, 887, 590, 278, 1, 3],
#  [203, 1, 18, 21, 4, 130, 19, 146, 27, 126, 719, 28, 236, 484],
#  [20, 57, 88, 74, 45, 27, 6, 153, 52, 44, 358, 5, 489, 471],
#  [421, 368, 1022, 13, 357],
#  [216, 12, 18, 152, 1, 496, 290, 275, 26, 645, 4, 452, 12, 153, 28],
#  [216, 12, 18, 152, 1, 496, 290, 275, 26, 645, 4, 452, 12, 153, 28],
#  [4,
#   267,
#   1295,
#   1,
#   273,
#   1677,
#   1179,
#   43,
#   10,
#   99,
#   1018,
#   12,
#   20,
#   708,
#   465,
#   8,
#   155,
#   107,
#   35,
#   74,
#   375],
#  [4,
#   267,
#   1295,
#   1,
#   273,
#   1677,
#   1179,
#   43,
#   10,
#   99,
#   1018,
#   12,
#   20,
#   708,
#   465,
#   8,
#   155,
#   107,
#   35,
#   74,
#   375],
#  [1,
#   164,
#   4,
#   8,
#   239,
#   125,
#   119,
#   35,
#   46,
#   239,
#   165,
#   44,
#   290,
#   269,
#   207,
#   187,
#   940,
#   263,
#   245,
#   523,
#   1678,
#   21,
#   4,
#   7,
#   1679,
#   211,
#   32,
#   312,
#   18],
#  [1,
#   164,
#   4,
#   8,
#   239,
#   125,
#   119,
#   35,
#   46,
#   239,
#   165,
#   44,
#   290,
#   269,
#   207,
#   187,
#   940,
#   263,
#   245,
#   523,
#   1678,
#   21,
#   4,
#   7,
#   1679,
#   211,
#   32,
#   312,
#   18],
#  [3, 18, 467, 9, 61, 14, 1, 61, 348, 312, 18, 21, 4],
#  [3, 18, 467, 9, 61, 14, 1, 61, 348, 312, 18, 21, 4],
#  [433, 86, 2, 8, 13, 239, 125, 119, 5, 1680, 471, 23, 1681, 277, 4],
#  [433, 86, 2, 8, 13, 239, 125, 119, 5, 1680, 471, 23, 1681, 277, 4],
#  [164,
#   4,
#   18,
#   77,
#   58,
#   24,
#   107,
#   260,
#   56,
#   428,
#   112,
#   66,
#   981,
#   539,
#   170,
#   509,
#   7,
#   715],
#  [164,
#   4,
#   18,
#   77,
#   58,
#   24,
#   107,
#   260,
#   56,
#   428,
#   112,
#   66,
#   981,
#   539,
#   170,
#   509,
#   7,
#   715],
#  [103, 1682, 1217, 140, 21, 21, 304, 130, 26, 71, 2],
#  [103, 1682, 1217, 140, 21, 21, 304, 130, 26, 71, 2],
#  [1484],
#  [16, 314, 858, 1296, 35, 170, 170, 806, 25, 15, 1470, 892, 61, 56],
#  [216, 45],
#  [26, 32, 97, 575, 224, 109, 142, 436, 222, 323],
#  [242, 62, 416, 21, 71, 343, 50, 189],
#  [240, 2],
#  [3,
#   1,
#   422,
#   244,
#   843,
#   170,
#   594,
#   83,
#   142,
#   9,
#   340,
#   879,
#   926,
#   82,
#   45,
#   63,
#   448,
#   245,
#   267,
#   621,
#   26,
#   1045,
#   448,
#   235,
#   280,
#   995,
#   585],
#  [3,
#   858,
#   61,
#   14,
#   64,
#   72,
#   1110,
#   269,
#   250,
#   124,
#   618,
#   55,
#   50,
#   1,
#   46,
#   62,
#   106,
#   165,
#   46,
#   62,
#   183,
#   23,
#   24,
#   17,
#   40,
#   170,
#   105,
#   17,
#   27,
#   6],
#  [7, 266, 149, 544, 53, 226, 1, 559, 490],
#  [4, 9, 61, 14, 73, 37, 924, 149, 175, 265, 253, 772, 646, 437, 854],
#  [9, 61, 14, 237, 260, 56, 74, 21, 4],
#  [212,
#   178,
#   249,
#   1137,
#   518,
#   330,
#   21,
#   71,
#   1004,
#   208,
#   859,
#   17,
#   15,
#   508,
#   70,
#   56,
#   11,
#   50,
#   161,
#   107],
#  [4, 1683, 618],
#  [143, 39, 2, 662, 12, 170, 203, 57, 283, 86, 72, 16, 707],
#  [4,
#   203,
#   57,
#   295,
#   161,
#   58,
#   12,
#   11,
#   71,
#   8,
#   44,
#   47,
#   15,
#   125,
#   56,
#   295,
#   65,
#   161,
#   76,
#   238,
#   40,
#   27,
#   6,
#   40,
#   323,
#   5,
#   56,
#   633,
#   17,
#   35,
#   859,
#   892,
#   44,
#   35,
#   369,
#   44,
#   892,
#   600,
#   1618,
#   56,
#   66,
#   786,
#   636,
#   76,
#   23,
#   425],
#  [32, 2, 124, 6, 124, 688, 419, 141, 265, 306, 110, 116, 140],
#  [19,
#   178,
#   518,
#   217,
#   8,
#   1297,
#   23,
#   105,
#   17,
#   25,
#   102,
#   256,
#   155,
#   283,
#   113,
#   6,
#   314,
#   141,
#   429,
#   48,
#   762],
#  [103,
#   39,
#   579,
#   871,
#   79,
#   69,
#   2,
#   114,
#   61,
#   112,
#   260,
#   56,
#   386,
#   426,
#   735,
#   416,
#   9,
#   396,
#   186,
#   1164,
#   174],
#  [4,
#   16,
#   8,
#   133,
#   20,
#   859,
#   17,
#   8,
#   43,
#   10,
#   9,
#   70,
#   65,
#   161,
#   249,
#   4,
#   282,
#   69,
#   785,
#   1,
#   15,
#   53,
#   5],
#  [64, 21, 71, 8, 112, 9, 1035, 220, 56, 40, 56, 633, 27, 6, 5, 425],
#  [1,
#   103,
#   39,
#   2,
#   242,
#   62,
#   72,
#   1089,
#   23,
#   79,
#   27,
#   6,
#   67,
#   169,
#   40,
#   1297,
#   35,
#   1684,
#   71,
#   7,
#   1298,
#   2,
#   144,
#   236,
#   1],
#  [1,
#   103,
#   39,
#   2,
#   242,
#   62,
#   72,
#   1089,
#   23,
#   79,
#   27,
#   6,
#   67,
#   169,
#   40,
#   1297,
#   35,
#   1684,
#   71,
#   7,
#   1298,
#   2,
#   144,
#   236,
#   1],
#  [250, 280, 45],
#  [212, 659, 17, 3, 262, 39, 2, 8, 398, 283, 1608, 170],
#  [427, 820, 4, 877, 15, 61, 204, 100, 72, 157, 25, 16, 13, 17],
#  [21, 4, 39, 8, 975, 170, 283, 667, 73],
#  [68, 44, 44, 11, 1, 299, 11, 5, 178],
#  [211, 168, 3, 970, 362, 45, 213, 5, 703, 898],
#  [185, 2, 178, 898, 211, 102, 28, 1445, 970, 6],
#  [3, 178, 467, 641, 518, 283, 189, 78, 37, 84, 12, 7, 2],
#  [3, 941, 618, 518, 21, 212, 60, 102, 7, 15, 453, 53, 27, 6, 3],
#  [505, 102, 506, 666, 1573, 843, 44, 67, 96, 20, 16, 362, 180],
#  [4, 12, 286, 74, 23, 154, 278, 37, 77, 23, 90],
#  [26, 21, 71, 178, 27, 6, 2, 185, 40, 439, 199, 37, 68, 141, 11, 4],
#  [9,
#   1275,
#   165,
#   155,
#   283,
#   869,
#   196,
#   461,
#   366,
#   859,
#   17,
#   8,
#   259,
#   44,
#   74,
#   58,
#   745,
#   173,
#   44,
#   21,
#   212,
#   84,
#   165,
#   27,
#   618,
#   36,
#   51],
#  [518, 178, 702, 26, 212, 28, 899, 361],
#  [21, 4, 58, 20, 440],
#  [1, 45, 158, 3, 115, 141, 218, 1168, 1112, 60, 36, 102, 28, 95, 744, 33],
#  [4, 265, 297, 632, 52, 33, 31, 65, 23, 42, 240],
#  [3, 1290, 29, 138, 45, 23, 42, 11, 115, 2, 123, 115, 386, 52, 33],
#  [3,
#   1290,
#   29,
#   35,
#   380,
#   138,
#   29,
#   240,
#   359,
#   42,
#   20,
#   36,
#   77,
#   115,
#   240,
#   67,
#   169,
#   2,
#   16,
#   105,
#   33],
#  [21, 4, 36, 140, 1479, 8, 292, 115, 95, 214],
#  [24, 700, 165, 72, 16, 449, 3, 10, 17, 115],
#  ...]

# %%
max_length = max([len(seq) for seq in X])
max_length
# Out:
# 135

# %%
X = np.array(pad_sequences(X, maxlen=max_length, padding='pre'))

# %% [markdown]
# ## 2.4 Split Dataset

# %%
Y = np.array([[y>1, y>2, y>3, y>4] for y in df.score])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

del X
del Y

# %% [markdown]
# ## 3 Build model

# %%
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers

# %%
model_input = layers.Input((max_length,))
l = layers.Embedding(n_words + 1, 64, input_length = max_length)(model_input)
l = layers.LSTM(64, activation='tanh', return_sequences=True)(l)
l = layers.Dropout(0.1)(l)
l = layers.LSTM(32, activation='tanh', return_sequences=False)(l)
l = layers.Dropout(0.2)(l)
l = layers.Dense(16, activation='relu')(l)
l = layers.Dropout(0.3)(l)
model_output = layers.Dense(4, activation='sigmoid')(l)

model = keras.Model(model_input, model_output)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 135)]             0
#
#  embedding (Embedding)       (None, 135, 64)           128064
#
#  lstm (LSTM)                 (None, 135, 64)           33024
#
#  dropout (Dropout)           (None, 135, 64)           0
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 16)                528
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_1 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 174,100
# Trainable params: 174,100
# Non-trainable params: 0
# _________________________________________________________________

# %%
def score_accuracy(y_true, y_pred):
    return tf.math.reduce_sum(y_true, axis=1) == tf.math.round(tf.math.reduce_sum(y_pred, axis=1))

def score_distance(y_true, y_pred):
    return tf.math.abs(tf.math.reduce_sum(y_true, axis=1) - tf.math.round(tf.math.reduce_sum(y_pred, axis=1)))

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(), loss = 'binary_crossentropy', metrics=[score_accuracy, score_distance])

# %%
hist = model.fit(
    X_train,
    y_train,
    batch_size=64,
    epochs=50,
    validation_data = (X_test, y_test)
)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 5s 63ms/step - loss: 0.6749 - score_accuracy: 0.2108 - score_distance: 1.2037 - val_loss: 0.6222 - val_score_accuracy: 0.2191 - val_score_distance: 1.1837
# Epoch 2/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.6248 - score_accuracy: 0.2126 - score_distance: 1.2188 - val_loss: 0.5962 - val_score_accuracy: 0.2191 - val_score_distance: 1.1837
# Epoch 3/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.6110 - score_accuracy: 0.2099 - score_distance: 1.2037 - val_loss: 0.5942 - val_score_accuracy: 0.2191 - val_score_distance: 1.1837
# Epoch 4/50
# 18/18 [==============================] - 0s 19ms/step - loss: 0.5933 - score_accuracy: 0.2188 - score_distance: 1.1860 - val_loss: 0.5486 - val_score_accuracy: 0.2191 - val_score_distance: 1.1802
# Epoch 5/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.5163 - score_accuracy: 0.2737 - score_distance: 1.0115 - val_loss: 0.4899 - val_score_accuracy: 0.3251 - val_score_distance: 0.9258
# Epoch 6/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.4328 - score_accuracy: 0.3472 - score_distance: 0.7830 - val_loss: 0.4418 - val_score_accuracy: 0.2898 - val_score_distance: 0.8481
# Epoch 7/50
# 18/18 [==============================] - 0s 19ms/step - loss: 0.3900 - score_accuracy: 0.3782 - score_distance: 0.7254 - val_loss: 0.4475 - val_score_accuracy: 0.2650 - val_score_distance: 0.8940
# Epoch 8/50
# 18/18 [==============================] - 0s 19ms/step - loss: 0.3504 - score_accuracy: 0.4278 - score_distance: 0.6430 - val_loss: 0.4403 - val_score_accuracy: 0.2933 - val_score_distance: 0.8622
# Epoch 9/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.3163 - score_accuracy: 0.4650 - score_distance: 0.5890 - val_loss: 0.4628 - val_score_accuracy: 0.2968 - val_score_distance: 0.8693
# Epoch 10/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.2902 - score_accuracy: 0.5004 - score_distance: 0.5412 - val_loss: 0.4807 - val_score_accuracy: 0.3781 - val_score_distance: 0.8021
# Epoch 11/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.2750 - score_accuracy: 0.5492 - score_distance: 0.4863 - val_loss: 0.5018 - val_score_accuracy: 0.4099 - val_score_distance: 0.8163
# Epoch 12/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.2513 - score_accuracy: 0.5784 - score_distance: 0.4553 - val_loss: 0.4954 - val_score_accuracy: 0.3958 - val_score_distance: 0.8163
# Epoch 13/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.2345 - score_accuracy: 0.5952 - score_distance: 0.4340 - val_loss: 0.5338 - val_score_accuracy: 0.4311 - val_score_distance: 0.7845
# Epoch 14/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.2067 - score_accuracy: 0.6652 - score_distance: 0.3490 - val_loss: 0.5261 - val_score_accuracy: 0.4417 - val_score_distance: 0.7385
# Epoch 15/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.1858 - score_accuracy: 0.7139 - score_distance: 0.3020 - val_loss: 0.5449 - val_score_accuracy: 0.4523 - val_score_distance: 0.7385
# Epoch 16/50
# 18/18 [==============================] - 0s 19ms/step - loss: 0.1723 - score_accuracy: 0.7059 - score_distance: 0.3109 - val_loss: 0.6020 - val_score_accuracy: 0.4240 - val_score_distance: 0.7597
# Epoch 17/50
# 18/18 [==============================] - 0s 19ms/step - loss: 0.1606 - score_accuracy: 0.7440 - score_distance: 0.2675 - val_loss: 0.6301 - val_score_accuracy: 0.4452 - val_score_distance: 0.7809
# Epoch 18/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.1521 - score_accuracy: 0.7405 - score_distance: 0.2728 - val_loss: 0.6585 - val_score_accuracy: 0.4346 - val_score_distance: 0.7456
# Epoch 19/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.1421 - score_accuracy: 0.7786 - score_distance: 0.2338 - val_loss: 0.6782 - val_score_accuracy: 0.4488 - val_score_distance: 0.7739
# Epoch 20/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.1388 - score_accuracy: 0.7697 - score_distance: 0.2374 - val_loss: 0.6790 - val_score_accuracy: 0.4417 - val_score_distance: 0.7633
# Epoch 21/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.1268 - score_accuracy: 0.8007 - score_distance: 0.2046 - val_loss: 0.7143 - val_score_accuracy: 0.4382 - val_score_distance: 0.7845
# Epoch 22/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.1122 - score_accuracy: 0.8468 - score_distance: 0.1621 - val_loss: 0.7159 - val_score_accuracy: 0.4382 - val_score_distance: 0.7527
# Epoch 23/50
# 18/18 [==============================] - 0s 19ms/step - loss: 0.1085 - score_accuracy: 0.8335 - score_distance: 0.1718 - val_loss: 0.7418 - val_score_accuracy: 0.4452 - val_score_distance: 0.7739
# Epoch 24/50
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0962 - score_accuracy: 0.8645 - score_distance: 0.1399 - val_loss: 0.8018 - val_score_accuracy: 0.4558 - val_score_distance: 0.7456
# Epoch 25/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0945 - score_accuracy: 0.8556 - score_distance: 0.1515 - val_loss: 0.8329 - val_score_accuracy: 0.4452 - val_score_distance: 0.7527
# Epoch 26/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0940 - score_accuracy: 0.8556 - score_distance: 0.1515 - val_loss: 0.8452 - val_score_accuracy: 0.4664 - val_score_distance: 0.7880
# Epoch 27/50
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0866 - score_accuracy: 0.8778 - score_distance: 0.1249 - val_loss: 0.8538 - val_score_accuracy: 0.4558 - val_score_distance: 0.7562
# Epoch 28/50
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0952 - score_accuracy: 0.8539 - score_distance: 0.1497 - val_loss: 0.9064 - val_score_accuracy: 0.4417 - val_score_distance: 0.8057
# Epoch 29/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0837 - score_accuracy: 0.8760 - score_distance: 0.1267 - val_loss: 0.8840 - val_score_accuracy: 0.4523 - val_score_distance: 0.7739
# Epoch 30/50
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0760 - score_accuracy: 0.8955 - score_distance: 0.1107 - val_loss: 0.8989 - val_score_accuracy: 0.4452 - val_score_distance: 0.7774
# Epoch 31/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0707 - score_accuracy: 0.8990 - score_distance: 0.1054 - val_loss: 0.9407 - val_score_accuracy: 0.4170 - val_score_distance: 0.8057
# Epoch 32/50
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0662 - score_accuracy: 0.8973 - score_distance: 0.1054 - val_loss: 0.9738 - val_score_accuracy: 0.4523 - val_score_distance: 0.7739
# Epoch 33/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0673 - score_accuracy: 0.9097 - score_distance: 0.0974 - val_loss: 0.9934 - val_score_accuracy: 0.4452 - val_score_distance: 0.7915
# Epoch 34/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0693 - score_accuracy: 0.9132 - score_distance: 0.0948 - val_loss: 1.0346 - val_score_accuracy: 0.4382 - val_score_distance: 0.8410
# Epoch 35/50
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0713 - score_accuracy: 0.8946 - score_distance: 0.1089 - val_loss: 1.0357 - val_score_accuracy: 0.4028 - val_score_distance: 0.8551
# Epoch 36/50
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0824 - score_accuracy: 0.8742 - score_distance: 0.1320 - val_loss: 1.0264 - val_score_accuracy: 0.4134 - val_score_distance: 0.8304
# Epoch 37/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0665 - score_accuracy: 0.9026 - score_distance: 0.1019 - val_loss: 1.0667 - val_score_accuracy: 0.4558 - val_score_distance: 0.8092
# Epoch 38/50
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0626 - score_accuracy: 0.9079 - score_distance: 0.0957 - val_loss: 1.0847 - val_score_accuracy: 0.4382 - val_score_distance: 0.8233
# Epoch 39/50
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0671 - score_accuracy: 0.9017 - score_distance: 0.1036 - val_loss: 1.0772 - val_score_accuracy: 0.4488 - val_score_distance: 0.8092
# Epoch 40/50
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0749 - score_accuracy: 0.9052 - score_distance: 0.0992 - val_loss: 1.1060 - val_score_accuracy: 0.4099 - val_score_distance: 0.8375
# Epoch 41/50
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0735 - score_accuracy: 0.8999 - score_distance: 0.1054 - val_loss: 1.0464 - val_score_accuracy: 0.4170 - val_score_distance: 0.8269
# Epoch 42/50
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0627 - score_accuracy: 0.9026 - score_distance: 0.1027 - val_loss: 1.1330 - val_score_accuracy: 0.4382 - val_score_distance: 0.8198
# Epoch 43/50
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0714 - score_accuracy: 0.8955 - score_distance: 0.1107 - val_loss: 1.1062 - val_score_accuracy: 0.4170 - val_score_distance: 0.8516
# Epoch 44/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0596 - score_accuracy: 0.9123 - score_distance: 0.0939 - val_loss: 1.1764 - val_score_accuracy: 0.4099 - val_score_distance: 0.8763
# Epoch 45/50
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0566 - score_accuracy: 0.9159 - score_distance: 0.0886 - val_loss: 1.1180 - val_score_accuracy: 0.4028 - val_score_distance: 0.8445
# Epoch 46/50
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0507 - score_accuracy: 0.9256 - score_distance: 0.0788 - val_loss: 1.1501 - val_score_accuracy: 0.4205 - val_score_distance: 0.8410
# Epoch 47/50
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0444 - score_accuracy: 0.9371 - score_distance: 0.0682 - val_loss: 1.1939 - val_score_accuracy: 0.4099 - val_score_distance: 0.8481
# Epoch 48/50
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0430 - score_accuracy: 0.9486 - score_distance: 0.0558 - val_loss: 1.2088 - val_score_accuracy: 0.4134 - val_score_distance: 0.8269
# Epoch 49/50
# 18/18 [==============================] - 0s 20ms/step - loss: 0.0397 - score_accuracy: 0.9451 - score_distance: 0.0593 - val_loss: 1.2725 - val_score_accuracy: 0.4205 - val_score_distance: 0.8198
# Epoch 50/50
# 18/18 [==============================] - 0s 21ms/step - loss: 0.0385 - score_accuracy: 0.9504 - score_distance: 0.0558 - val_loss: 1.2944 - val_score_accuracy: 0.4205 - val_score_distance: 0.8233

# %%
model.save(f'../models/{name}')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses, lstm_cell_17_layer_call_fn, lstm_cell_17_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/amz_lstm\assets
# INFO:tensorflow:Assets written to: ../models/amz_lstm\assets

# %%
hist_df = pd.DataFrame(hist.history)
hist_df
# Out:
#        loss  score_accuracy  score_distance  val_loss  val_score_accuracy  \
# 0  0.286148        0.595460        0.532812  0.256647            0.620506
# 1  0.257084        0.638911        0.467674  0.242685            0.658240
# 2  0.242488        0.660764        0.433344  0.234738            0.678937
# 3  0.231100        0.676634        0.408674  0.228477            0.688603
# 4  0.220312        0.692570        0.384097  0.225654            0.703407
#
#    val_score_distance
# 0            0.484181
# 1            0.440958
# 2            0.414510
# 3            0.399495
# 4            0.383161

# %%
hist_df.to_csv(f'../logs/{name}.csv')

# %%
plt.title('CNN on BoW data')

plt.plot(hist_df.score_accuracy, label='Training')
plt.plot(hist_df.val_score_accuracy, label='Validation')

plt.legend()
plt.xlabel('epoch')
plt.ylabel('accuracy')

plt.savefig(f'../figs/{name}.png')
plt.show()
